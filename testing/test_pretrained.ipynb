# %%
import os
import torch
import cv2
from ultralytics import YOLO
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# %%
model_path = '../datasets/shopping-trolley-5/runs/detect/pretrainedv8n/weights/bestpretrainedv8n.pt'
image_path = '../shopping-trolley-5/test/images'
label_path = '../shopping-trolley-5/test/labels'
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = YOLO(model_path)
model = model.to(device)
# model.eval()

# %%
def predict_images(image_dir):
    predictions = []
    images = []
    filenames = []
    for filename in os.listdir(image_dir):
        if filename.endswith('.jpg'):
            path = os.path.join(image_dir, filename)
            image = cv2.imread(path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image_tensor = torch.from_numpy(image).float() / 255.0
            image_tensor = image_tensor.permute(2, 0, 1).unsqueeze(0)

            # print(image, image.shape)
            with torch.no_grad():
                detections = model(image_tensor, verbose=False)
                predictions.append(detections[0].boxes.xywh / 640)
            
            images.append(image_tensor)
            filenames.append(filename)

    return predictions, images, filenames
            
def load_labels(label_dir):
    labels = []
    for filename in os.listdir(label_dir):
        if filename.endswith('.txt'):
            path = os.path.join(label_dir, filename)
            with open(path, 'r') as file:
                labels[filename[:-4]] = file.readlines()
    return labels

def compute_metrics(predictions, true_labels):
    return 0

# %%
def bboxvisualization(img_tensor, edgecolor=None, labels_ground=None, labels_xyxy=None, transforms=None):
    if labels_ground is not None:  # Also means there is a transform performed
        _, cx, cy, w, h = labels_ground
        transformed_size = img_tensor.shape[-2:]  # the resized shape
        x1 = (cx - w / 2) * transformed_size[0]
        y1 = (cy - h / 2) * transformed_size[1]
        x2 = (cx + w / 2) * transformed_size[0]
        y2 = (cy + h / 2) * transformed_size[1]
    else:
        x1, y1, x2, y2 = labels_xyxy.cpu().numpy()

    fig, ax = plt.subplots(1)
    # Convert the tensor to format suitable for imshow
    img_display = img_tensor # Adjusting channel position for matplotlib
    if img_display.shape[2] == 1:  # If the image is grayscale, convert it to 'RGB' for proper display
        img_display = img_display.repeat(1, 1, 3)
    ax.imshow(img_display.cpu().numpy())  # Ensure tensor is moved to CPU and converted to numpy for display
    rect = patches.Rectangle((x1, y1), x2 - x1, y2 - y1, linewidth=2, edgecolor=edgecolor if edgecolor else 'r', facecolor='none')
    ax.add_patch(rect)
    plt.tight_layout()
    plt.axis("off")
    plt.show()

# %%
def print_groundtruth(filename, label_path):
    path = os.path.join(label_path, filename + '.txt')
    with open(path, 'r') as file:
        lines = file.readlines()
        for line in lines:
            line = line.split(' ')
            label = int(line[0])
            x = float(line[1])
            y = float(line[2])
            w = float(line[3])
            h = float(line[4])
            print(label, x, y, w, h)

# %%
predictions, image, filename = predict_images(image_path)
# labels = load_labels(label_path)

for i in range(len(predictions)):
    print(filename[i])
    print()
    print_groundtruth(filename[i][:-4], label_path)
    print()
    print(predictions[i])
    print('\n\n')
# print()
# print(predictions[-1])  
# print(len(predictions))
# bboxvisualization(image, labels_xyxy = predictions[0][0])
# Out:
# 00826_jpg.rf.2e2e220f59b934cae4a574b8c7a43e7a.jpg
#
# 1 0.5921875 0.7390625 0.1921875 0.40703125
#
# tensor([[0.6209, 0.7625, 0.1509, 0.4489],
#         [0.1033, 0.8686, 0.2061, 0.2629],
#         [0.1553, 0.8645, 0.1351, 0.2703],
#         [0.7467, 0.9071, 0.3923, 0.1859],
#         [0.8002, 0.8998, 0.2886, 0.2001],
#         [0.0783, 0.8988, 0.1548, 0.2024]], device='cuda:0')
#
#
#
# 01RRATHAEXT4_jpg.rf.7b50b7fa5d0b676121e99bf237f35dd8.jpg
#
# 1 0.47265625 0.66015625 0.5421875 0.5875
#
# tensor([[0.4698, 0.6682, 0.5301, 0.5669]], device='cuda:0')
#
#
#
# 0463_jpg.rf.eca07f4f2da1e58cf3a4fa1941737121.jpg
#
# 1 0.5546875 0.5984375 0.153125 0.46328125
# 1 0.15 0.79921875 0.28671875 0.4015625
# 1 0.74140625 0.5578125 0.109375 0.2484375
#
# tensor([[0.1481, 0.8010, 0.2960, 0.3980],
#         [0.5484, 0.6170, 0.1480, 0.4122],
#         [0.7387, 0.5558, 0.1018, 0.2530]], device='cuda:0')
#
#
#
# 05DDU4JUP6VQ_jpg.rf.4e4bcedf30f8f0fe7b266fff0c736600.jpg
#
# 0 0.5140625 0.6421875 0.453125 0.45390625
#
# tensor([[0.5767, 0.6337, 0.2821, 0.4613],
#         [0.5037, 0.6362, 0.4256, 0.4630],
#         [0.4241, 0.6381, 0.2745, 0.4535]], device='cuda:0')
#
#
#
# 05XEO29LEZAB_jpg.rf.d197ae112e4c0b9019378d02176d427d.jpg
#
# 0 0.5015625 0.49765625 0.30546875 0.58671875
#
# tensor([[0.4978, 0.4997, 0.2895, 0.5927],
#         [0.8191, 0.2548, 0.1781, 0.2949],
#         [0.9175, 0.2141, 0.1527, 0.2271]], device='cuda:0')
#
#
#
# 0J2FFIJ3GZTO_jpg.rf.cdd800c6693320af4cabf8c887a16cd1.jpg
#
# 0 0.3859375 0.5875 0.309375 0.50234375
#
# tensor([[0.3814, 0.5759, 0.3041, 0.4789],
#         [0.3829, 0.6192, 0.2966, 0.5635]], device='cuda:0')
#
#
#
# 0MKB0PGIIPIP_jpg.rf.7b1c1c1f705da47f0930350440ba56b1.jpg
#
# 1 0.49375 0.53359375 0.85859375 0.6703125
#
# tensor([[0.4963, 0.5428, 0.7723, 0.6705]], device='cuda:0')
#
#
#
# 0U1IA2K4D2RI_jpg.rf.530a96d4b029c03c7ee7e72d7032679d.jpg
#
# 0 0.67734375 0.5546875 0.08359375 0.13515625
# 1 0.21796875 0.60625 0.10078125 0.171875
# 1 0.63359375 0.56484375 0.0859375 0.13359375
# 1 0.5640625 0.5703125 0.04765625 0.12421875
#
# tensor([[0.2247, 0.6084, 0.1223, 0.1593],
#         [0.6832, 0.5566, 0.0683, 0.1336],
#         [0.3541, 0.6220, 0.1255, 0.0930],
#         [0.5974, 0.5628, 0.1086, 0.1460],
#         [0.6331, 0.5562, 0.1735, 0.1391]], device='cuda:0')
#
#
#
# 0_jpg.rf.8b6a8c999d76a0c5d534a6769dea783e.jpg
#
# 1 0.4890625 0.68125 0.48828125 0.63671875
#
# tensor([[0.4882, 0.6738, 0.4850, 0.6523]], device='cuda:0')
#
#
#
# 105-2-_jpg.rf.5e76947110178a165cb4f5939002818a.jpg
#
# 1 0.71875 0.46875 0.4046875 0.59609375
#
# tensor([[0.7197, 0.4624, 0.4157, 0.6027]], device='cuda:0')
#
#
#
# 108UY218EPN1_jpg.rf.82d189df57c1f8bfc6371442de1ca0b9.jpg
#
# 1 0.64140625 0.503125 0.64296875 0.99375
#
# tensor([[0.7163, 0.4952, 0.5100, 0.9881]], device='cuda:0')
#
#
#
# 129_jpg.rf.21c0c5d92e3dfd17e8fd7f2a70ff6602.jpg
#
# 1 0.50078125 0.58203125 0.93828125 0.71484375
#
# tensor([[0.4855, 0.5897, 0.9542, 0.7309]], device='cuda:0')
#
#
#
# 133R0K7Z4P66_jpg.rf.fafacd2e1dca0eba4d8fcd25ef35b15e.jpg
#
# 1 0.715625 0.225 0.56796875 0.3421875
# 1 0.5 0.69140625 1.0 0.6171875
#
# tensor([[0.5005, 0.3465, 0.9989, 0.6930],
#         [0.5006, 0.3068, 0.9942, 0.6135]], device='cuda:0')
#
#
#
# 135_jpg.rf.8af72c719a357c710146cb8bdaf3eadc.jpg
#
# 1 0.4984375 0.49765625 0.80546875 0.98828125
#
# tensor([[0.4946, 0.4995, 0.8197, 0.9952]], device='cuda:0')
#
#
#
# 144-2-_jpg.rf.ceb0813138710016d9dd7f74e17c0b31.jpg
#
# 1 0.578125 0.45078125 0.76484375 0.540625
#
# tensor([[0.5833, 0.4491, 0.7766, 0.5513]], device='cuda:0')
#
#
#
# 148_jpg.rf.57161be5dbe98a0308678d4afaa12849.jpg
#
# 1 0.68359375 0.8078125 0.63203125 0.384375
#
# tensor([[0.6735, 0.8103, 0.6478, 0.3789]], device='cuda:0')
#
#
#
# 152-2-_jpg.rf.0d3c9546790b588eb2f0892de0e92559.jpg
#
# 1 0.52421875 0.49375 0.621875 0.7921875
#
# tensor([[0.4985, 0.4723, 0.6421, 0.7703]], device='cuda:0')
#
#
#
# 167_jpg.rf.be1962cf3a847f9a0b622f76794e65d8.jpg
#
# 1 0.475 0.49140625 0.859375 0.8953125
#
# tensor([[0.4807, 0.5008, 0.8647, 0.8968]], device='cuda:0')
#
#
#
# 17-3-_jpg.rf.f6e65c5ce3fb0d63c12f8034e19e596f.jpg
#
# 1 0.34375 0.46796875 0.6640625 0.87734375
#
# tensor([[0.3374, 0.4631, 0.6545, 0.8882]], device='cuda:0')
#
#
#
# 175_jpg.rf.23da14b5c5d2a63977802ecf41dda938.jpg
#
# 1 0.51484375 0.56484375 0.8046875 0.8640625
#
# tensor([[0.5185, 0.5625, 0.8155, 0.8650]], device='cuda:0')
#
#
#
# 175_jpg.rf.ad4135289e66690bf07b45a83a7d15a5.jpg
#
# 1 0.5125 0.55859375 0.8171875 0.87109375
#
# tensor([[0.5199, 0.5608, 0.8090, 0.8611]], device='cuda:0')
#
#
#
# 17_jpg.rf.dd63a0e197766181cd2eaa941199726b.jpg
#
# 1 0.72265625 0.52578125 0.53125 0.678125
#
# tensor([[0.7153, 0.5300, 0.5156, 0.6595]], device='cuda:0')
#
#
#
# 199-2-_jpg.rf.1c0132b71d5308039b13fedcb4633c73.jpg
#
# 1 0.5171875 0.46875 0.84765625 0.7625
#
# tensor([[0.5203, 0.4725, 0.8500, 0.7847]], device='cuda:0')
#
#
#
# 199H7QMCZNV0_jpg.rf.510fda0af6301c9ebca829bc96e62982.jpg
#
# 1 0.1875 0.40078125 0.27265625 0.43125
# 1 0.49453125 0.41328125 0.27734375 0.453125
#
# tensor([[0.1898, 0.4065, 0.2790, 0.4430],
#         [0.4930, 0.4079, 0.2796, 0.4420]], device='cuda:0')
#
#
#
# 1DCC56G35X89_jpg.rf.b51a2d43f8744462f50b1fc6d274b9f4.jpg
#
# 1 0.43203125 0.78671875 0.1875 0.27265625
#
# tensor([[0.4269, 0.7883, 0.1769, 0.2685]], device='cuda:0')
#
#
#
# 1IQLU2TF73SG_jpg.rf.6c84759b67ee3f5de99b577452f52416.jpg
#
# 1 0.39765625 0.51875 0.215625 0.26640625
# 1 0.584375 0.5640625 0.23125 0.321875
#
# tensor([[0.4011, 0.5178, 0.2183, 0.2846],
#         [0.5887, 0.5690, 0.2251, 0.3120]], device='cuda:0')
#
#
#
# 1KWRE7MCYB3J_jpg.rf.dde6854632347e4eadf076b0da90666f.jpg
#
# 1 0.70078125 0.67578125 0.38984375 0.51640625
#
# tensor([[0.6978, 0.6839, 0.3455, 0.5114]], device='cuda:0')
#
#
#
# 1MP9Y2W1845G_jpg.rf.abb25ec2518b5de73342dd4943c311ae.jpg
#
# 0 0.8171875 0.3625 0.340625 0.596875
#
# tensor([[0.8079, 0.3757, 0.3655, 0.6101],
#         [0.8066, 0.3706, 0.3680, 0.5820]], device='cuda:0')
#
#
#
# 1MW7WT7PHOAL_jpg.rf.00a4f61a8c7f79683ca999ad6192480e.jpg
#
# 1 0.15234375 0.38359375 0.2421875 0.278125
# 1 0.59921875 0.35390625 0.2546875 0.2578125
#
# tensor([[0.5978, 0.3857, 0.2504, 0.2863],
#         [0.1505, 0.4326, 0.2494, 0.3716]], device='cuda:0')
#
#
#
# 1O7M74KYOCPB_jpg.rf.2bcfda3df2b25c228257eb4cc2af2d30.jpg
#
# 1 0.540625 0.625 0.4859375 0.521875
#
# tensor([[0.5474, 0.6350, 0.4775, 0.5069]], device='cuda:0')
#
#
#
# 1_frame0_jpg.rf.f682aff60415b5141abec3f5968f973f.jpg
#
# 0 0.56953125 0.465625 0.1703125 0.246875
#
# tensor([[0.5656, 0.4642, 0.1742, 0.2300]], device='cuda:0')
#
#
#
# 203-2-_jpg.rf.6d594345b380fd2ba5b2223baeddaf42.jpg
#
# 1 0.49453125 0.5140625 0.59609375 0.69140625
#
# tensor([[0.4931, 0.5185, 0.6216, 0.6858]], device='cuda:0')
#
#
#
# 203_jpg.rf.b5aab3a85d181e9797c7d0d7cdd3d847.jpg
#
# 1 0.521875 0.49140625 0.859375 0.94140625
#
# tensor([[0.5103, 0.4850, 0.8895, 0.9520]], device='cuda:0')
#
#
#
# 212LLYYH5B0E_jpg.rf.4a8435513b0c0aaae821b047b2f3c146.jpg
#
# 1 0.590625 0.65546875 0.49609375 0.584375
#
# tensor([[0.5944, 0.6721, 0.5249, 0.6143]], device='cuda:0')
#
#
#
# 22-3-_jpg.rf.b136e124c30a636ebf21187689f3596f.jpg
#
# 1 0.46015625 0.5171875 0.89375 0.81015625
#
# tensor([[0.4603, 0.5316, 0.9200, 0.8010]], device='cuda:0')
#
#
#
# 232_jpg.rf.56d22a146b81e478f659733fb21711cf.jpg
#
# 1 0.50625 0.50390625 0.91015625 0.98671875
#
# tensor([[0.5039, 0.4994, 0.9085, 0.9988]], device='cuda:0')
#
#
#
# 232_jpg.rf.901b81a51bdd00711ce8462181d6a307.jpg
#
# 1 0.503125 0.5015625 0.89609375 0.98515625
#
# tensor([[0.5090, 0.4988, 0.9200, 0.9949]], device='cuda:0')
#
#
#
# 234-2-_jpg.rf.95c589418b8f78a8e98e2eb03bf8ef85.jpg
#
# 1 0.50390625 0.46328125 0.46640625 0.6671875
#
# tensor([[0.5018, 0.4639, 0.4729, 0.6520]], device='cuda:0')
#
#
#
# 240_jpg.rf.5924a8b491373d2395a76c1db04b8ff2.jpg
#
# 1 0.3140625 0.8375 0.62734375 0.32421875
#
# tensor([[0.3151, 0.8439, 0.6302, 0.3123]], device='cuda:0')
#
#
#
# 241_jpg.rf.050be4a4fffe6229a1b630274a4bcdf9.jpg
#
# 1 0.4421875 0.60390625 0.7078125 0.7421875
#
# tensor([[0.4427, 0.6040, 0.7111, 0.7558]], device='cuda:0')
#
#
#
# 244_jpg.rf.3110fb6a8e7fa6f9766db0603c10a020.jpg
#
# 1 0.15078125 0.240625 0.2671875 0.44609375
# 1 0.84453125 0.24296875 0.2640625 0.459375
# 1 0.16875 0.75703125 0.2953125 0.4578125
# 1 0.64140625 0.67109375 0.178125 0.28671875
# 1 0.86328125 0.81171875 0.234375 0.34765625
# 1 0.49453125 0.240625 0.2296875 0.44609375
#
# tensor([[0.8673, 0.8033, 0.2358, 0.3456],
#         [0.1699, 0.7517, 0.3053, 0.4514],
#         [0.8461, 0.2442, 0.2815, 0.4495],
#         [0.5029, 0.2400, 0.2461, 0.4518],
#         [0.1530, 0.2459, 0.2687, 0.4446],
#         [0.6369, 0.7509, 0.2014, 0.4458]], device='cuda:0')
#
#
#
# 246-2-_jpg.rf.ab21bda983b67ab6adebe387299289e4.jpg
#
# 1 0.48984375 0.52265625 0.771875 0.7921875
#
# tensor([[0.4880, 0.5071, 0.7780, 0.8070]], device='cuda:0')
#
#
#
# 247_jpg.rf.a52ea78951e3405cb2067cc254fd7d5d.jpg
#
# 1 0.4625 0.4984375 0.74140625 0.803125
#
# tensor([[0.4515, 0.4965, 0.7543, 0.8003]], device='cuda:0')
#
#
#
# 258_jpg.rf.e775e35a3de0e55283938bc7f5b1d985.jpg
#
# 1 0.46953125 0.55078125 0.52734375 0.89765625
#
# tensor([[0.4648, 0.5382, 0.5281, 0.9237]], device='cuda:0')
#
#
#
# 260_jpg.rf.2230ce75f0cd056ccf3fde76e5c64be0.jpg
#
# 1 0.58671875 0.83125 0.59296875 0.3375
#
# tensor([[0.5975, 0.8364, 0.5805, 0.3273]], device='cuda:0')
#
#
#
# 262_jpg.rf.0d977823845d1542583330921b02e7b7.jpg
#
# 1 0.1953125 0.7453125 0.390625 0.50859375
#
# tensor([[0.1948, 0.7484, 0.3892, 0.5028]], device='cuda:0')
#
#
#
# 267_jpg.rf.6f634028c1ac82ccea84b71640ad5a90.jpg
#
# 1 0.478125 0.5796875 0.38125 0.4359375
#
# tensor([[0.4757, 0.5761, 0.3658, 0.4358]], device='cuda:0')
#
#
#
# 275_jpg.rf.c33dc2f3896f8e986d3ec5192b5be059.jpg
#
# 1 0.21796875 0.49921875 0.36796875 0.83984375
#
# tensor([[0.2218, 0.5238, 0.3833, 0.8564]], device='cuda:0')
#
#
#
# 280_jpg.rf.9f760fe5f48a4074eecc0f23544dddf2.jpg
#
# 1 0.38359375 0.47421875 0.4 0.43828125
#
# tensor([[0.3926, 0.4753, 0.4219, 0.4378]], device='cuda:0')
#
#
#
# 282_jpg.rf.d8b2205552356017716864f2db13781a.jpg
#
# 1 0.71796875 0.76875 0.2546875 0.4625
#
# tensor([[0.7155, 0.7749, 0.2491, 0.4502]], device='cuda:0')
#
#
#
# 298_jpg.rf.6ae846daed49aadaac9901aac1311677.jpg
#
# 1 0.48515625 0.69296875 0.6875 0.46640625
#
# tensor([[0.4752, 0.6908, 0.7393, 0.4762]], device='cuda:0')
#
#
#
# 2DDA6T5DLNNH_jpg.rf.275a726e1652fc87ca9fef55f8d47468.jpg
#
# 1 0.528125 0.6984375 0.4859375 0.603125
#
# tensor([[0.5171, 0.7094, 0.4693, 0.5812]], device='cuda:0')
#
#
#
# 2EWMSL06OTDD_jpg.rf.987cef6c4ba4b42420ea267accf08833.jpg
#
# 1 0.36484375 0.3546875 0.44921875 0.43828125
#
# tensor([[0.3665, 0.3509, 0.4487, 0.4229]], device='cuda:0')
#
#
#
# 2KNR8SSH68GO_jpg.rf.f54dc0f735f473c7a50bbcd61b047c48.jpg
#
# 1 0.5171875 0.590625 0.85625 0.64609375
#
# tensor([[0.5160, 0.5924, 0.8614, 0.6524]], device='cuda:0')
#
#
#
# 2OSAOQZ1AG4T_jpg.rf.a688d05c90a5bdd859ef3ae440dcde2b.jpg
#
# 1 0.3109375 0.5875 0.40078125 0.46484375
#
# tensor([[0.3106, 0.5890, 0.4029, 0.4680]], device='cuda:0')
#
#
#
# 2TIN7T3ICGJW_jpg.rf.2aed282882bc36b04a21cdb6db6d4ad2.jpg
#
# 0 0.44140625 0.484375 0.6734375 0.9125
#
# tensor([[0.4349, 0.4865, 0.6729, 0.9149]], device='cuda:0')
#
#
#
# 2VPMTPQOYY4N_jpg.rf.186fd099b517a943c1cac5e106ff5372.jpg
#
# 1 0.534375 0.4734375 0.61328125 0.8625
#
# tensor([[0.5285, 0.4802, 0.6085, 0.8407]], device='cuda:0')
#
#
#
# 2Y9WO1AL1VPV_jpg.rf.3ebdf9490102aaddfe908d5a83a3c516.jpg
#
# 1 0.3703125 0.4671875 0.54375 0.8109375
#
# tensor([[0.3716, 0.4719, 0.5472, 0.7231]], device='cuda:0')
#
#
#
# 2YB90XR2WKOF_jpg.rf.6f3cdd70b1b1c5d4bd47c461e614c56c.jpg
#
# 1 0.65390625 0.75546875 0.6921875 0.4890625
#
# tensor([[0.6381, 0.7457, 0.7236, 0.5081],
#         [0.4336, 0.1362, 0.1452, 0.1291],
#         [0.2885, 0.2055, 0.1035, 0.0998]], device='cuda:0')
#
#
#
# 2_frame60_jpg.rf.c76a7b1e9665c54ae67e69cbeba4db61.jpg
#
# 0 0.42421875 0.496875 0.84765625 0.86796875
#
# tensor([[0.4119, 0.4821, 0.8239, 0.8581]], device='cuda:0')
#
#
#
# 31-2-_jpg.rf.0bb07736a272bfe6027c4f01c219543a.jpg
#
# 1 0.5796875 0.478125 0.7703125 0.56328125
#
# tensor([[0.5795, 0.4695, 0.7761, 0.5558]], device='cuda:0')
#
#
#
# 317_jpg.rf.a36ac5d0987948a14c6ece517a5d84c1.jpg
#
# 1 0.47421875 0.49453125 0.7796875 0.8953125
#
# tensor([[0.4629, 0.4939, 0.7805, 0.9121]], device='cuda:0')
#
#
#
# 318_jpg.rf.3720e6534fca229ca205a2decb9b25ce.jpg
#
# 1 0.63125 0.765625 0.61796875 0.46875
#
# tensor([[0.6367, 0.7620, 0.6109, 0.4761]], device='cuda:0')
#
#
#
# 325_jpg.rf.e08839db5e5018d8a84b46ebc6ca4d51.jpg
#
# 1 0.47265625 0.52421875 0.621875 0.6015625
#
# tensor([[0.4776, 0.5222, 0.6223, 0.6037]], device='cuda:0')
#
#
#
# 329_jpg.rf.4ff011d2f6ef2dd5dd419a54efb24715.jpg
#
# 1 0.51015625 0.49453125 0.9109375 0.92734375
#
# tensor([[0.5118, 0.4916, 0.9236, 0.9394]], device='cuda:0')
#
#
#
# 330_jpg.rf.2311cbfae8ab922fb25246048b511b5b.jpg
#
# 1 0.48671875 0.521875 0.87734375 0.8671875
#
# tensor([[0.4840, 0.5180, 0.8921, 0.8678]], device='cuda:0')
#
#
#
# 340ITNO3T9OC_jpg.rf.fe3f486da7419aac7b1459bb98392b85.jpg
#
# 1 0.46640625 0.553125 0.5046875 0.7484375
#
# tensor([[0.4623, 0.5462, 0.5072, 0.7216]], device='cuda:0')
#
#
#
# 341_jpg.rf.f087d4f08d95891d4621fc92310ce9e9.jpg
#
# 1 0.77421875 0.71484375 0.4515625 0.56953125
#
# tensor([[0.7776, 0.7138, 0.4448, 0.5724]], device='cuda:0')
#
#
#
# 349_jpg.rf.6ef5bc8387a139c191fc8f4049e9d748.jpg
#
# 1 0.36796875 0.7796875 0.7359375 0.43984375
#
# tensor([[0.3707, 0.7899, 0.7412, 0.4201]], device='cuda:0')
#
#
#
# 356_jpg.rf.50b39a2fa87a9cfd28116fffe22e3c90.jpg
#
# 1 0.4640625 0.73515625 0.159375 0.434375
#
# tensor([[0.4661, 0.7334, 0.1443, 0.4400]], device='cuda:0')
#
#
#
# 360_jpg.rf.dc62f9add4e23550f4e5a6f200d18bf3.jpg
#
# 1 0.49296875 0.534375 0.60078125 0.865625
#
# tensor([[0.4937, 0.5127, 0.6327, 0.9339]], device='cuda:0')
#
#
#
# 37304H31RTJB_jpg.rf.e5d10a413fac78a7c40089c3875a36b8.jpg
#
# 1 0.315625 0.6703125 0.47578125 0.4203125
#
# tensor([[0.3136, 0.6677, 0.4678, 0.4205]], device='cuda:0')
#
#
#
# 37_jpg.rf.48bdbd65cb200e19fa2d1bc8ee09ddd1.jpg
#
# 1 0.496875 0.74375 0.59375 0.51171875
#
# tensor([[0.4997, 0.7362, 0.6019, 0.5274]], device='cuda:0')
#
#
#
# 382_jpg.rf.9fb52b87d201d2cb6298c86e8fd214e7.jpg
#
# 1 0.2484375 0.55625 0.496875 0.78125
#
# tensor([[0.2527, 0.5820, 0.5038, 0.8097],
#         [0.0224, 0.2264, 0.0441, 0.2263]], device='cuda:0')
#
#
#
# 384_jpg.rf.68fc505741f81a602d1fc832c15ff01a.jpg
#
# 1 0.25859375 0.23828125 0.44140625 0.45546875
# 1 0.778125 0.24140625 0.4390625 0.4734375
# 1 0.225 0.725 0.4359375 0.47890625
# 1 0.73984375 0.7453125 0.45234375 0.49296875
#
# tensor([[0.2268, 0.7250, 0.4360, 0.4786],
#         [0.7785, 0.2406, 0.4345, 0.4733],
#         [0.7405, 0.7509, 0.4424, 0.4905],
#         [0.2595, 0.2360, 0.4540, 0.4640]], device='cuda:0')
#
#
#
# 386-2-_jpg.rf.52d4ab1149eb9eeddaa7c8e9396ef278.jpg
#
# 1 0.4734375 0.4859375 0.4265625 0.88515625
#
# tensor([[0.4755, 0.4764, 0.4381, 0.8889],
#         [0.0805, 0.1018, 0.1611, 0.2030],
#         [0.8890, 0.0996, 0.2214, 0.1993]], device='cuda:0')
#
#
#
# 386_jpg.rf.2971549d2450b800ba63857867067662.jpg
#
# 1 0.69296875 0.73203125 0.6140625 0.5359375
#
# tensor([[0.6793, 0.7305, 0.6412, 0.5390]], device='cuda:0')
#
#
#
# 390_jpg.rf.ba214536d2264b1d648c414d853dc331.jpg
#
# 1 0.4734375 0.56640625 0.3234375 0.509375
#
# tensor([[0.4712, 0.5740, 0.3209, 0.5086]], device='cuda:0')
#
#
#
# 39_jpg.rf.60e77c91d6871aea321fa66ffef7ec5c.jpg
#
# 1 0.37265625 0.63515625 0.7 0.625
#
# tensor([[0.3739, 0.6485, 0.7014, 0.6121]], device='cuda:0')
#
#
#
# 3AQIJP8PP91K_jpg.rf.ade421ca46cdc13fbae692ff6eccbf25.jpg
#
# 1 0.56484375 0.8640625 0.8703125 0.271875
#
# tensor([[0.5525, 0.8540, 0.8591, 0.2919]], device='cuda:0')
#
#
#
# 3E89WKHXQFSP_jpg.rf.d6cbe13d2cec1c2c4777df572a968d44.jpg
#
# 1 0.4921875 0.4953125 0.9078125 0.9109375
#
# tensor([[0.4893, 0.5009, 0.8813, 0.9280]], device='cuda:0')
#
#
#
# 3F5QHT5HK7TT_jpg.rf.c836d5281db9bec23a8f2c0efb9dc66f.jpg
#
# 1 0.8359375 0.67734375 0.25546875 0.52421875
#
# tensor([[0.8323, 0.6736, 0.2551, 0.5124],
#         [0.3053, 0.3684, 0.1050, 0.1483],
#         [0.1766, 0.3658, 0.1382, 0.1968]], device='cuda:0')
#
#
#
# 3WPKXI9GYTWC_jpg.rf.9a5bc551abec10a79af19b249f56f5f9.jpg
#
# 1 0.5078125 0.5 0.95390625 0.7234375
#
# tensor([[0.5355, 0.4881, 0.9136, 0.7641]], device='cuda:0')
#
#
#
# 401-2-_jpg.rf.b0b88fa93fa246642b2dcb565a10659e.jpg
#
# 1 0.484375 0.675 0.85703125 0.61171875
#
# tensor([[0.4847, 0.6746, 0.8597, 0.5963]], device='cuda:0')
#
#
#
# 401_jpg.rf.4c4976778ba79eee97959ddbc29f2923.jpg
#
# 1 0.49765625 0.5015625 0.98203125 0.98203125
#
# tensor([[0.5007, 0.4999, 0.9987, 0.9954]], device='cuda:0')
#
#
#
# 417_jpg.rf.3c1a655c63811977367bae2a89e79a97.jpg
#
# 1 0.6234375 0.753125 0.18046875 0.49375
#
# tensor([[0.6185, 0.7500, 0.1918, 0.4994]], device='cuda:0')
#
#
#
# 41_jpg.rf.dc635c07b0d3aeac990c51574503bbf6.jpg
#
# 1 0.43203125 0.65234375 0.278125 0.55625
#
# tensor([[0.4287, 0.6665, 0.2810, 0.5659]], device='cuda:0')
#
#
#
# 429_jpg.rf.42b281c230c4d55a5adaedf375475666.jpg
#
# 1 0.30546875 0.6328125 0.61015625 0.63984375
# 1 0.70625 0.35703125 0.5703125 0.64921875
#
# tensor([[0.5001, 0.3763, 0.9998, 0.6682],
#         [0.3699, 0.5541, 0.7374, 0.7989]], device='cuda:0')
#
#
#
# 430_jpg.rf.46fe3585435db82f793c76acdf1efd07.jpg
#
# 1 0.39765625 0.5453125 0.35859375 0.80078125
#
# tensor([[0.3958, 0.5347, 0.3684, 0.7798]], device='cuda:0')
#
#
#
# 434_jpg.rf.6df7c8a3549d7f20fd42108017002cdc.jpg
#
# 1 0.478125 0.7296875 0.65390625 0.37109375
#
# tensor([[0.4698, 0.7336, 0.6516, 0.3703],
#         [0.1872, 0.1045, 0.3745, 0.2090]], device='cuda:0')
#
#
#
# 43N6XLS0V62U_jpg.rf.0660cfb3c0dcbda58a0a8d5c800d4ca6.jpg
#
# 0 0.38125 0.65859375 0.36953125 0.2921875
# 0 0.5734375 0.634375 0.3 0.25078125
#
# tensor([[0.3699, 0.6584, 0.3463, 0.2858],
#         [0.5829, 0.6360, 0.2739, 0.2559]], device='cuda:0')
#
#
#
# 450_jpg.rf.1b34a77ad2db550f4ea98489618046fc.jpg
#
# 1 0.5 0.70390625 1.0 0.4671875
#
# tensor([[0.5001, 0.7014, 0.9997, 0.4902]], device='cuda:0')
#
#
#
# 45582SYXQAX9_jpg.rf.1af1c3b74666cb6e4e02a8d3cb8c500b.jpg
#
# 1 0.50703125 0.4984375 0.90234375 0.83046875
#
# tensor([[0.5029, 0.5128, 0.8999, 0.8655]], device='cuda:0')
#
#
#
# 456-2-_jpg.rf.1464852a7fb50590466b19a706ce32cc.jpg
#
# 1 0.49765625 0.50859375 0.43046875 0.79453125
#
# tensor([[0.4948, 0.5054, 0.4460, 0.7907]], device='cuda:0')
#
#
#
# 456_jpg.rf.7b6769284cb1f8c9c548f34656ef196e.jpg
#
# 1 0.5109375 0.503125 0.67421875 0.89609375
#
# tensor([[0.5146, 0.5104, 0.7279, 0.9539]], device='cuda:0')
#
#
#
# 465-3-_jpg.rf.8ea04b9ca34a37d249f3e18b249a0342.jpg
#
# 1 0.5953125 0.43046875 0.65390625 0.32578125
#
# tensor([[0.6005, 0.4319, 0.6704, 0.3364]], device='cuda:0')
#
#
#
# 471_jpg.rf.971faeaf6a7138d894a32e7a30a6bd06.jpg
#
# 0 0.4703125 0.53203125 0.81328125 0.90390625
#
# tensor([[0.4829, 0.5336, 0.7892, 0.8837],
#         [0.0890, 0.0587, 0.1780, 0.1173]], device='cuda:0')
#
#
#
# 474_jpg.rf.340d335ad34cfb39bfcbb558173b0f91.jpg
#
# 1 0.553125 0.5765625 0.784375 0.703125
#
# tensor([[0.5461, 0.5830, 0.7754, 0.7012]], device='cuda:0')
#
#
#
# 492_jpg.rf.17e28a4b7bd83b12340bb3bcf0a6874d.jpg
#
# 1 0.53203125 0.5 0.83984375 0.88203125
#
# tensor([[0.5250, 0.5106, 0.8324, 0.8764]], device='cuda:0')
#
#
#
# 4af8646537d29cc2_jpg.rf.f98e50cfe2396bca99a81f511a6a1549.jpg
#
# 0 0.26015625 0.62890625 0.2921875 0.5140625
# 0 0.48515625 0.57421875 0.32890625 0.54140625
# 0 0.70390625 0.55234375 0.31953125 0.5359375
#
# tensor([[0.2675, 0.6276, 0.3350, 0.5158],
#         [0.7046, 0.5558, 0.3311, 0.5427],
#         [0.4869, 0.5895, 0.3341, 0.5667],
#         [0.4862, 0.4797, 0.3444, 0.3316]], device='cuda:0')
#
#
#
# 4CYJVMB0KPC8_jpg.rf.7f825d8fa4793c99c3a614ca7b28131a.jpg
#
# 0 0.16015625 0.7609375 0.20859375 0.30859375
#
# tensor([[0.1577, 0.7609, 0.2122, 0.2971]], device='cuda:0')
#
#
#
# 4V6HEOTVT8TI_jpg.rf.08ec29ef3cd8cac2afab05f867dccd66.jpg
#
# 1 0.3796875 0.65859375 0.7375 0.6828125
#
# tensor([[0.6757, 0.0673, 0.2261, 0.1345],
#         [0.4045, 0.6058, 0.8090, 0.7861],
#         [0.4017, 0.6125, 0.8035, 0.7750]], device='cuda:0')
#
#
#
# 4WGVWHR7ZK0Q_jpg.rf.4ea1dbf3cf7d78cb2803c98b06c69630.jpg
#
# 0 0.7890625 0.57890625 0.38359375 0.5984375
# 1 0.25703125 0.71953125 0.3953125 0.36328125
#
# tensor([[0.7894, 0.5762, 0.3821, 0.5991],
#         [0.2504, 0.7278, 0.3884, 0.4327]], device='cuda:0')
#
#
#
# 4YGM32W3CZ14_jpg.rf.b98b9c9bfadb49174a3bd427bdaf58f2.jpg
#
# 1 0.640625 0.56328125 0.6296875 0.55703125
#
# tensor([[0.6374, 0.5386, 0.6137, 0.5023]], device='cuda:0')
#
#
#
# 4ZX6AHVVGIY0_jpg.rf.e0949cfea64df155c369548113e41a8c.jpg
#
# 0 0.5421875 0.6640625 0.40234375 0.46640625
# 0 0.815625 0.65390625 0.36875 0.36328125
# 0 0.19453125 0.6765625 0.21953125 0.1875
#
# tensor([[0.8630, 0.6654, 0.2731, 0.3667],
#         [0.6258, 0.6570, 0.4399, 0.4086],
#         [0.6839, 0.6667, 0.3190, 0.3813],
#         [0.7688, 0.6678, 0.3500, 0.3756],
#         [0.6503, 0.6260, 0.5513, 0.4677],
#         [0.3018, 0.6920, 0.2430, 0.3223],
#         [0.3687, 0.6235, 0.3753, 0.4620]], device='cuda:0')
#
#
#
# 4_jpg.rf.ff22e1d2246906e54594fb150d691f19.jpg
#
# 1 0.50859375 0.76640625 0.51328125 0.4671875
#
# tensor([[0.5090, 0.7639, 0.5056, 0.4717]], device='cuda:0')
#
#
#
# 50-2-_jpg.rf.3b5c096715d760a4116b0658be4eb2cb.jpg
#
# 1 0.49140625 0.4625 0.46875 0.63984375
#
# tensor([[0.4888, 0.4655, 0.4799, 0.6264]], device='cuda:0')
#
#
#
# 502_jpg.rf.be838f336acb71fb34a92194ae38b083.jpg
#
# 1 0.72265625 0.46328125 0.540625 0.7875
#
# tensor([[0.7082, 0.4724, 0.5127, 0.7684]], device='cuda:0')
#
#
#
# 51-3-_jpg.rf.f0626259270f101a018d5aa985d5d150.jpg
#
# 1 0.50703125 0.49375 0.6234375 0.88984375
#
# tensor([[0.4950, 0.4778, 0.6598, 0.8920]], device='cuda:0')
#
#
#
# 515_jpg.rf.fb6cf2337bef0ca5abb8f6d120d7dabc.jpg
#
# 1 0.478125 0.5078125 0.6953125 0.96484375
#
# tensor([[0.4728, 0.5299, 0.6938, 0.9361]], device='cuda:0')
#
#
#
# 517_jpg.rf.fa4db9ca3a7bebce936039518666e2c8.jpg
#
# 1 0.48125 0.6359375 0.3140625 0.55703125
#
# tensor([[0.4817, 0.6365, 0.3193, 0.5569]], device='cuda:0')
#
#
#
# 523_jpg.rf.d5d4b850bc227d31e8e49be7b34dbef4.jpg
#
# 1 0.4265625 0.69609375 0.80546875 0.6078125
#
# tensor([[0.4191, 0.6825, 0.8224, 0.6350]], device='cuda:0')
#
#
#
# 5322bcd1766ab523_jpg.rf.7b3e1d3761ee89c4be2af11c66dcca23.jpg
#
# 1 0.42265625 0.55625 0.62421875 0.8875
# 1 0.78125 0.24140625 0.2953125 0.43125
#
# tensor([[0.4086, 0.5785, 0.6232, 0.8253]], device='cuda:0')
#
#
#
# 550OEX39GUN1_jpg.rf.15e7308e9bd205f6da25d879c06da9cd.jpg
#
# 1 0.52578125 0.65078125 0.55234375 0.659375
#
# tensor([[0.5087, 0.6509, 0.5854, 0.6814]], device='cuda:0')
#
#
#
# 550_jpg.rf.6852f893dbf17422e8552db07133c90f.jpg
#
# 1 0.46796875 0.4828125 0.50859375 0.965625
#
# tensor([[0.5474, 0.4836, 0.7453, 0.9673]], device='cuda:0')
#
#
#
# 558_jpg.rf.348fbb4658695921c9a3e9e1942e700a.jpg
#
# 1 0.271875 0.5171875 0.52265625 0.73046875
#
# tensor([[0.2672, 0.4995, 0.5120, 0.7572]], device='cuda:0')
#
#
#
# 563_jpg.rf.2cf580d5a6801f0b53c84084f7baf65a.jpg
#
# 1 0.48359375 0.78046875 0.74765625 0.2921875
#
# tensor([[0.4970, 0.7748, 0.8137, 0.3148]], device='cuda:0')
#
#
#
# 59_jpg.rf.79767dd203d7da7bb2efef147496427f.jpg
#
# 1 0.5203125 0.878125 0.43125 0.24375
#
# tensor([[0.5113, 0.8769, 0.4386, 0.2461]], device='cuda:0')
#
#
#
# 5QXBFB2OYVBP_jpg.rf.85998188f7b96eb5b39ef8d839bcf1f6.jpg
#
# 0 0.503125 0.49765625 0.28828125 0.44296875
#
# tensor([[0.5038, 0.4981, 0.2800, 0.4424]], device='cuda:0')
#
#
#
# 5RY23I9LHCC0_jpg.rf.2a60f613eb24094e2f09e22cd82cc5e1.jpg
#
# 1 0.5234375 0.51640625 0.653125 0.9671875
#
# tensor([[0.5276, 0.4883, 0.6560, 0.9166]], device='cuda:0')
#
#
#
# 5ULOG300YGJX_jpg.rf.69cfb7aa3811cee8de3dd6cc7f649c92.jpg
#
# 1 0.50390625 0.53515625 0.6546875 0.615625
#
# tensor([[0.4992, 0.5427, 0.6568, 0.5896],
#         [0.6118, 0.5361, 0.4218, 0.5977]], device='cuda:0')
#
#
#
# 5XGO6FVYKG1P_jpg.rf.51ca16a656a086a95129d34ae8ab39ab.jpg
#
# 0 0.54140625 0.41796875 0.86484375 0.6078125
#
# tensor([[0.5417, 0.4185, 0.8610, 0.6194]], device='cuda:0')
#
#
#
# 5YLTV0H4O9YY_jpg.rf.86e27b6be2a62c9080d35cfc42562322.jpg
#
# 1 0.7296875 0.51640625 0.53984375 0.9671875
#
# tensor([[0.5021, 0.5401, 0.9957, 0.9198]], device='cuda:0')
#
#
#
# 603_jpg.rf.8dc7dbdcd0a8f253eca4042a112a6dd3.jpg
#
# 1 0.49921875 0.43828125 0.8203125 0.72578125
#
# tensor([[0.4969, 0.4382, 0.8210, 0.7049]], device='cuda:0')
#
#
#
# 605_jpg.rf.921204db9a4a38da2663be13f4300acd.jpg
#
# 1 0.60546875 0.615625 0.525 0.62109375
#
# tensor([[0.5882, 0.6093, 0.5554, 0.6263]], device='cuda:0')
#
#
#
# 60_jpg.rf.01efb13c484455b65f1215438a62a89f.jpg
#
# 1 0.490625 0.5359375 0.63984375 0.7109375
#
# tensor([[0.4925, 0.5293, 0.6170, 0.7085]], device='cuda:0')
#
#
#
# 60_jpg.rf.958dfc18df1df2913006c865790f9ea7.jpg
#
# 1 0.48671875 0.52265625 0.64609375 0.696875
#
# tensor([[0.4848, 0.5264, 0.6389, 0.7032]], device='cuda:0')
#
#
#
# 61-2-_jpg.rf.72ef32edb7c8c5c54e9751172d6b6686.jpg
#
# 1 0.66875 0.35546875 0.4609375 0.54921875
#
# tensor([[0.6677, 0.3496, 0.4640, 0.5591]], device='cuda:0')
#
#
#
# 615_jpg.rf.72bf6e18006710b86def8aa949492a3a.jpg
#
# 1 0.4734375 0.52421875 0.696875 0.859375
#
# tensor([[0.4783, 0.5200, 0.7032, 0.8594]], device='cuda:0')
#
#
#
# 62HXT39A5P0L_jpg.rf.9382f5220b1b4df844f09f8df0a96d32.jpg
#
# 1 0.6328125 0.640625 0.4390625 0.525
# 1 0.15234375 0.60078125 0.3046875 0.3984375
#
# tensor([[0.1422, 0.4822, 0.2844, 0.6451],
#         [0.6985, 0.6628, 0.2527, 0.5685],
#         [0.6135, 0.6640, 0.4351, 0.5695]], device='cuda:0')
#
#
#
# 633e4f482895b176_jpg.rf.4df2b400c080b8f9bf6f3201ec0d3b18.jpg
#
# 1 0.3359375 0.60078125 0.340625 0.5203125
#
# tensor([[0.3417, 0.5964, 0.3097, 0.5176]], device='cuda:0')
#
#
#
# 657LXAAVJC59_jpg.rf.af78e9df2208931edd5112d608edf9a6.jpg
#
# 1 0.259375 0.73359375 0.453125 0.390625
# 0 0.74765625 0.73828125 0.50390625 0.39609375
#
# tensor([[0.2419, 0.7136, 0.4346, 0.3427],
#         [0.7436, 0.7509, 0.4926, 0.3989],
#         [0.0508, 0.7527, 0.1017, 0.2654]], device='cuda:0')
#
#
#
# 683_jpg.rf.9758adc8f817a78dfe1198d35729be62.jpg
#
# 1 0.50625 0.5046875 0.8171875 0.68828125
#
# tensor([[0.5005, 0.5056, 0.8151, 0.6868]], device='cuda:0')
#
#
#
# 6F2HBHD2RMAK_jpg.rf.1c138ace299eb148b2c2df6c32b16500.jpg
#
# 0 0.4734375 0.675 0.446875 0.403125
#
# tensor([[0.4763, 0.6765, 0.4318, 0.4193],
#         [0.4106, 0.6753, 0.3013, 0.4190]], device='cuda:0')
#
#
#
# 6GT7THS8VKB6_jpg.rf.b046f3c775292238fe84a5b935a51e0c.jpg
#
# 1 0.50625 0.5921875 0.90390625 0.6640625
#
# tensor([[0.5061, 0.5882, 0.8992, 0.6757]], device='cuda:0')
#
#
#
# 6HNHG1IEVOZ4_jpg.rf.62c7b14d5334eab8acca5a9cfd9402de.jpg
#
# 0 0.2515625 0.29921875 0.35703125 0.5984375
#
# tensor([[0.2556, 0.2965, 0.3751, 0.5924]], device='cuda:0')
#
#
#
# 6WMR4ZRDO80N_jpg.rf.6de037dd4c326d518e96d5d0fcfaea50.jpg
#
# 0 0.56796875 0.646875 0.328125 0.4578125
#
# tensor([[0.5782, 0.6050, 0.3084, 0.3791],
#         [0.6284, 0.6275, 0.4174, 0.3996]], device='cuda:0')
#
#
#
# 6WPKROYYIIC9_jpg.rf.38e3b1ba8347016b70f474a1d6e7c6f5.jpg
#
# 1 0.55859375 0.496875 0.21796875 0.2890625
# 1 0.8296875 0.54375 0.17109375 0.33203125
#
# tensor([[0.5601, 0.4947, 0.2159, 0.2942],
#         [0.8242, 0.5420, 0.1566, 0.3244],
#         [0.1259, 0.2874, 0.2515, 0.5594]], device='cuda:0')
#
#
#
# 70L6B89LBNXD_jpg.rf.4928a852893ec0f39d1ddd002beaa97a.jpg
#
# 0 0.440625 0.321875 0.60703125 0.44921875
#
# tensor([[0.4394, 0.3221, 0.6208, 0.4520]], device='cuda:0')
#
#
#
# 724_jpg.rf.f2028ab253c6d66adfb625db72dd8015.jpg
#
# 1 0.515625 0.46015625 0.92890625 0.61640625
#
# tensor([[0.5086, 0.4690, 0.9372, 0.6467]], device='cuda:0')
#
#
#
# 730R5FLEF19H_jpg.rf.4c2d3cc58e5fb8df79e74acad033d33b.jpg
#
# 0 0.5546875 0.74609375 0.490625 0.421875
#
# tensor([[0.5548, 0.7410, 0.4911, 0.4290]], device='cuda:0')
#
#
#
# 739_jpg.rf.14e59575799b733aa7dd43af1e2c3cbb.jpg
#
# 1 0.49921875 0.47890625 0.92421875 0.9078125
#
# tensor([[0.4953, 0.4909, 0.9284, 0.9245]], device='cuda:0')
#
#
#
# 73_jpg.rf.4d2b82dce8ef493ffd6671d932aa3354.jpg
#
# 1 0.71875 0.5234375 0.3203125 0.88203125
#
# tensor([[0.7161, 0.5172, 0.3318, 0.8595]], device='cuda:0')
#
#
#
# 73_jpg.rf.60d7a25458b45ca5bba371434c01f523.jpg
#
# 1 0.715625 0.52109375 0.32578125 0.853125
#
# tensor([[0.7142, 0.5133, 0.3293, 0.8602]], device='cuda:0')
#
#
#
# 74-2-_jpg.rf.7a1ee60e15388082bb517d20417352f1.jpg
#
# 1 0.5078125 0.49453125 0.87578125 0.91875
#
# tensor([[0.4969, 0.4944, 0.8927, 0.9585]], device='cuda:0')
#
#
#
# 747_jpg.rf.b09df8a089d2e4d9e117aeb05329ea4e.jpg
#
# 1 0.51796875 0.484375 0.81328125 0.66015625
#
# tensor([[0.5237, 0.4850, 0.8131, 0.6615]], device='cuda:0')
#
#
#
# 749_jpg.rf.b813f255f1f92f4d60320d6bbae66462.jpg
#
# 1 0.61953125 0.57578125 0.553125 0.76171875
#
# tensor([[0.6303, 0.5720, 0.5265, 0.7860]], device='cuda:0')
#
#
#
# 74SK9TP1RMW4_jpg.rf.bbcfaa2a5a25b59d9209b0e9689fea01.jpg
#
# 1 0.68359375 0.5125 0.0609375 0.121875
#
# tensor([[0.6804, 0.5128, 0.0705, 0.1246],
#         [0.7547, 0.5076, 0.0515, 0.1121],
#         [0.3435, 0.6595, 0.1326, 0.3045],
#         [0.2067, 0.6408, 0.1602, 0.2800]], device='cuda:0')
#
#
#
# 75_jpg.rf.9a5702c1f770ee1192e9a04cb7798a38.jpg
#
# 1 0.5921875 0.46328125 0.68515625 0.83359375
#
# tensor([[0.5951, 0.5084, 0.5940, 0.7335]], device='cuda:0')
#
#
#
# 76-2-_jpg.rf.f392b6d4ed8598938bdfe015e9a7a2c9.jpg
#
# 1 0.4953125 0.46484375 0.9 0.6734375
#
# tensor([[0.4960, 0.4744, 0.9081, 0.6824]], device='cuda:0')
#
#
#
# 76KW2NBQYZBG_jpg.rf.fc88d7e85232744a63989fc81f63f9d7.jpg
#
# 1 0.41875 0.61875 0.378125 0.7625
#
# tensor([[0.4173, 0.6148, 0.3918, 0.7705]], device='cuda:0')
#
#
#
# 77-2-_jpg.rf.47eacbe7d999adf87e075624dd216137.jpg
#
# 1 0.48359375 0.49921875 0.8640625 0.896875
#
# tensor([[0.5022, 0.4964, 0.8440, 0.9359]], device='cuda:0')
#
#
#
# 79UX7CQQ44GC_jpg.rf.08871be6cd5483563b46a7959715c288.jpg
#
# 1 0.490625 0.634375 0.55390625 0.54609375
#
# tensor([[0.4814, 0.6327, 0.5350, 0.5379]], device='cuda:0')
#
#
#
# 7DWE342004GN_jpg.rf.1f43e61fbc4d8a7c404d0485f7d4055c.jpg
#
# 1 0.5390625 0.51015625 0.5453125 0.90625
#
# tensor([[0.5343, 0.4922, 0.5543, 0.9103]], device='cuda:0')
#
#
#
# 7fdc6b8e99f33718_jpg.rf.c16aa815a3f4c168f74ed7ea81a2da12.jpg
#
# 1 0.49375 0.63984375 0.3140625 0.509375
# 1 0.8765625 0.671875 0.24609375 0.415625
#
# tensor([[0.4985, 0.6353, 0.3248, 0.4963],
#         [0.8818, 0.6667, 0.2364, 0.4746]], device='cuda:0')
#
#
#
# 7OSQI6262YUO_jpg.rf.449db7dd9c6de844c935dbbcf1ce879b.jpg
#
# 1 0.61640625 0.67734375 0.44140625 0.53984375
#
# tensor([[0.6153, 0.6804, 0.4551, 0.5532]], device='cuda:0')
#
#
#
# 88_jpg.rf.34cdccfecead3c42829fe9b80dae7f68.jpg
#
# 1 0.49765625 0.7796875 0.76328125 0.440625
#
# tensor([[0.5017, 0.7725, 0.7589, 0.4550]], device='cuda:0')
#
#
#
# 8BO7O9N4PZUA_jpg.rf.95288f11abc3df595ccf1031199cf681.jpg
#
# 0 0.3796875 0.66484375 0.2125 0.38515625
#
# tensor([[0.3807, 0.6681, 0.2158, 0.3957]], device='cuda:0')
#
#
#
# 8CIAF11LCL8O_jpg.rf.109f620f1ee321e7d17ee30b42a2b077.jpg
#
# 0 0.4734375 0.68515625 0.61015625 0.62890625
#
# tensor([[0.4657, 0.6820, 0.6439, 0.6361],
#         [0.3406, 0.6803, 0.3918, 0.6268]], device='cuda:0')
#
#
#
# 8O3S69RST32B_jpg.rf.8d0d10a7aafde78a610915d0b9a031d3.jpg
#
# 0 0.4328125 0.796875 0.865625 0.40625
#
# tensor([[0.4505, 0.7991, 0.9000, 0.3996]], device='cuda:0')
#
#
#
# 8UI6M1Z6URRS_jpg.rf.551b8d8dad7cc03f0e1030998cbbac84.jpg
#
# 1 0.3875 0.73828125 0.63125 0.45234375
#
# tensor([[0.3935, 0.7337, 0.6409, 0.4471]], device='cuda:0')
#
#
#
# 8VNN0V3RZF6N_jpg.rf.3c638759eece5a18e4a90c5c44adf9cb.jpg
#
# 1 0.6765625 0.73203125 0.46328125 0.3234375
#
# tensor([[0.6666, 0.7389, 0.4391, 0.3181]], device='cuda:0')
#
#
#
# 8W2GC0MCFZQ3_jpg.rf.30c8ed9cc18f4c8b6a7da5688124a490.jpg
#
# 1 0.50234375 0.76484375 0.53203125 0.4703125
#
# tensor([[0.4974, 0.7586, 0.5385, 0.4823]], device='cuda:0')
#
#
#
# 8YKZY25D3LAP_jpg.rf.ed8c04909e47de3bedba8672f4c351fd.jpg
#
# 0 0.5109375 0.5328125 0.78984375 0.696875
#
# tensor([[0.4989, 0.5393, 0.7439, 0.6821]], device='cuda:0')
#
#
#
# 8_frame120_jpg.rf.5201be0fed9fa9c25f04382abad2a857.jpg
#
# 0 0.5 0.66796875 1.0 0.6640625
#
# tensor([[0.5007, 0.6401, 0.9987, 0.6951]], device='cuda:0')
#
#
#
# 8_frame150_jpg.rf.88bf1aefd11788f24d8586af72c62627.jpg
#
# 0 0.4609375 0.72421875 0.921875 0.5515625
#
# tensor([[0.4946, 0.7107, 0.9892, 0.5748]], device='cuda:0')
#
#
#
# 8_frame60_jpg.rf.25dca506e742ad9795b2777acc1658a2.jpg
#
# 0 0.44921875 0.60234375 0.89765625 0.79140625
#
# tensor([[0.4717, 0.5892, 0.9434, 0.7825]], device='cuda:0')
#
#
#
# 90_jpg.rf.7e86daa0586b6efe5cd0860545c47491.jpg
#
# 0 0.28125 0.83359375 0.328125 0.3328125
#
# tensor([[0.2754, 0.8366, 0.3187, 0.3268]], device='cuda:0')
#
#
#
# 96RJJ3YTVW2B_jpg.rf.4e784ab7c7a77f0d6c946b26b5b7d9c0.jpg
#
# 0 0.28828125 0.565625 0.43203125 0.5390625
#
# tensor([[0.2820, 0.5631, 0.4079, 0.5565]], device='cuda:0')
#
#
#
# 98_jpg.rf.a9fec4da3c6d27a81545a8856e7bda8b.jpg
#
# 1 0.5421875 0.52578125 0.6828125 0.75
#
# tensor([[0.5484, 0.5286, 0.6760, 0.7500]], device='cuda:0')
#
#
#
# 990bc1885d8a980a_jpg.rf.b2d1c82dc03f248378333d938baaed04.jpg
#
# 1 0.56875 0.7046875 0.25859375 0.440625
#
# tensor([[0.5718, 0.7041, 0.2505, 0.4531]], device='cuda:0')
#
#
#
# 9M669AIGQDJ6_jpg.rf.5a0135012aa86789a72f7a15b518e356.jpg
#
# 1 0.5109375 0.50703125 0.3890625 0.5203125
#
# tensor([[0.5105, 0.5150, 0.3924, 0.5343]], device='cuda:0')
#
#
#
# 9NQOF4I6GQK7_jpg.rf.69003f62592f6900877f3d278ecf7bd7.jpg
#
# 0 0.453125 0.6953125 0.165625 0.309375
# 0 0.053125 0.66328125 0.10625 0.3140625
# 1 0.14375 0.68203125 0.19453125 0.2625
# 0 0.628125 0.70703125 0.15546875 0.32421875
# 1 0.81953125 0.71796875 0.21875 0.35703125
#
# tensor([[0.4622, 0.6990, 0.1800, 0.3128],
#         [0.8028, 0.7218, 0.2510, 0.3478],
#         [0.1550, 0.6853, 0.1757, 0.2632],
#         [0.0505, 0.6574, 0.1011, 0.3241],
#         [0.6235, 0.7046, 0.1566, 0.3261],
#         [0.6229, 0.7054, 0.1594, 0.3226]], device='cuda:0')
#
#
#
# 9YLKGD6SSG5Y_jpg.rf.3dbb6e5510e9312d2f2957d9b3635efc.jpg
#
# 1 0.29375 0.6484375 0.3140625 0.23828125
#
# tensor([[0.2865, 0.6484, 0.3246, 0.2386]], device='cuda:0')
#
#
#
# A88M6NP5DM7J_jpg.rf.a1b48f8f4f66e6c67026cce275792ad8.jpg
#
# 0 0.6640625 0.6921875 0.4875 0.615625
#
# tensor([[0.6599, 0.6915, 0.4855, 0.6170]], device='cuda:0')
#
#
#
# AAMPNSOU543Y_jpg.rf.883e39fed60c98d4cdb485891938e340.jpg
#
# 0 0.34921875 0.4359375 0.47890625 0.5890625
#
# tensor([[0.3478, 0.4818, 0.4884, 0.5086]], device='cuda:0')
#
#
#
# ace2ddf1328724a6_jpg.rf.3ad650aaeab312f4ae87e9f5fc25ab59.jpg
#
# 1 0.60390625 0.7046875 0.60234375 0.58984375
#
# tensor([[0.6197, 0.7058, 0.6198, 0.5866]], device='cuda:0')
#
#
#
# AEDKRMBXS7YT_jpg.rf.6ad2826bd0db22e1cf890dacd06b29d0.jpg
#
# 1 0.496875 0.4953125 0.5703125 0.828125
#
# tensor([[0.4832, 0.4941, 0.5820, 0.9882]], device='cuda:0')
#
#
#
# AHALLHBVRJ7Q_jpg.rf.51fcb4acb7e95168ebeda8dd3b68c3c3.jpg
#
# 1 0.51484375 0.59453125 0.47890625 0.75390625
#
# tensor([[0.5155, 0.5947, 0.4817, 0.7627]], device='cuda:0')
#
#
#
# ANTFDOYWP91G_jpg.rf.ba92254b95cde56ab0bfd2463483f047.jpg
#
# 1 0.6796875 0.50546875 0.5828125 0.93515625
#
# tensor([[0.6825, 0.5156, 0.5871, 0.9187]], device='cuda:0')
#
#
#
# B0U0QPARLOG8_jpg.rf.9c9ed225109865d94b218b936a472f96.jpg
#
# 1 0.34453125 0.76328125 0.1953125 0.28125
#
# tensor([[0.3442, 0.7623, 0.1980, 0.2835]], device='cuda:0')
#
#
#
# B1AZ13ZSWC11_jpg.rf.76ca69c541d745f7f0f8c30413655da0.jpg
#
# 1 0.5359375 0.52890625 0.17421875 0.32109375
#
# tensor([[0.5291, 0.5187, 0.1614, 0.2993]], device='cuda:0')
#
#
#
# B3E91UZUYNMV_jpg.rf.6c4df0419ddb72cafb29cec824ee16e4.jpg
#
# 0 0.53984375 0.7078125 0.915625 0.584375
#
# tensor([[0.5371, 0.7076, 0.9208, 0.5848]], device='cuda:0')
#
#
#
# B65B0BKCNKYB_jpg.rf.a2904e322ed8a48043b3f83d3b0e3010.jpg
#
# 0 0.26171875 0.49921875 0.271875 0.3703125
#
# tensor([[0.2618, 0.5001, 0.2811, 0.3756]], device='cuda:0')
#
#
#
# B6JR3RRXGGOH_jpg.rf.cb3d9f2e29d42cbc3b2bce8a0e1e10dc.jpg
#
# 1 0.60703125 0.47734375 0.64609375 0.68046875
#
# tensor([[0.5805, 0.4797, 0.6650, 0.6824]], device='cuda:0')
#
#
#
# B7LQGM6XEW3Q_jpg.rf.b782cec3cdfea97945e7c432ded4add7.jpg
#
# 1 0.35546875 0.728125 0.5546875 0.54296875
#
# tensor([[0.4073, 0.7287, 0.4619, 0.5243]], device='cuda:0')
#
#
#
# BEWSD20TF21C_jpg.rf.b0e3e0ca00473b4f07401e94d98a3020.jpg
#
# 0 0.7109375 0.33359375 0.24375 0.225
#
# tensor([[0.7150, 0.3336, 0.2163, 0.2103]], device='cuda:0')
#
#
#
# BIQL9SED45W8_jpg.rf.e489277bcf782fcb92e52c5b4092a98b.jpg
#
# 1 0.51328125 0.59296875 0.1375 0.3421875
#
# tensor([[0.5140, 0.5974, 0.1370, 0.3243]], device='cuda:0')
#
#
#
# BRGHAUV8NEYU_jpg.rf.ffba64f9e24a1cdb134e6036a5888d20.jpg
#
# 1 0.13984375 0.3796875 0.16875 0.2890625
# 1 0.43359375 0.765625 0.4625 0.340625
# 1 0.82578125 0.81171875 0.34765625 0.37578125
# 1 0.6859375 0.53046875 0.25546875 0.20703125
# 1 0.2953125 0.5078125 0.1234375 0.178125
# 1 0.58203125 0.39296875 0.19140625 0.1140625
# 1 0.37109375 0.37265625 0.21796875 0.10546875
# 1 0.503125 0.3171875 0.15234375 0.0625
# 1 0.3703125 0.2765625 0.12890625 0.0640625
#
# tensor([[0.1232, 0.2649, 0.1946, 0.5287],
#         [0.4217, 0.7982, 0.5360, 0.4035]], device='cuda:0')
#
#
#
# C4PNMZSDBOG6_jpg.rf.3d3d2c84fbb7e73500525b1b99be86af.jpg
#
# 1 0.653125 0.6984375 0.6875 0.603125
#
# tensor([[0.6454, 0.6997, 0.7079, 0.5977]], device='cuda:0')
#
#
#
# C8L2N68NPHZK_jpg.rf.e6d8c2425edc4c8b46ae194a510ea0f8.jpg
#
# 1 0.26015625 0.4125 0.28125 0.40703125
#
# tensor([[0.2581, 0.4094, 0.2961, 0.4127]], device='cuda:0')
#
#
#
# C8RYKEKZ5A3G_jpg.rf.6cc34ae2d6970994ad12e30925ac111e.jpg
#
# 0 0.621875 0.5359375 0.446875 0.55703125
#
# tensor([[0.5172, 0.5296, 0.3575, 0.5625]], device='cuda:0')
#
#
#
# c9eecd5c7770d299_jpg.rf.012eea85fe79b635bd4aab96a255dff3.jpg
#
# 0 0.44296875 0.584375 0.70234375 0.83046875
# 1 0.1171875 0.63046875 0.234375 0.7390625
#
# tensor([[0.4164, 0.5993, 0.7486, 0.7970],
#         [0.1220, 0.5630, 0.2441, 0.7528],
#         [0.1167, 0.4259, 0.2334, 0.4937]], device='cuda:0')
#
#
#
# CMZRVXNLYPDE_jpg.rf.aef9867ce306d42f66bf21ecf056d0e1.jpg
#
# 1 0.5703125 0.36484375 0.4109375 0.64140625
#
# tensor([[0.5675, 0.3237, 0.4115, 0.5609],
#         [0.5032, 0.7234, 0.4460, 0.4527]], device='cuda:0')
#
#
#
# CPGON0L3AR3A_jpg.rf.ae3f2ca4afb59c6e898936efa1ae28f6.jpg
#
# 1 0.50859375 0.65234375 0.35234375 0.41328125
#
# tensor([[0.5289, 0.6666, 0.2841, 0.3492]], device='cuda:0')
#
#
#
# CYIYY0CSB4WZ_jpg.rf.15c1a0129bef2b9a1c41960be9e31a17.jpg
#
# 1 0.334375 0.72890625 0.615625 0.43984375
#
# tensor([[0.3479, 0.7307, 0.6642, 0.4336]], device='cuda:0')
#
#
#
# D1WW828HG629_jpg.rf.151001c2cdbedecce823e0ac8404592b.jpg
#
# 1 0.465625 0.6359375 0.15390625 0.215625
#
# tensor([[0.4682, 0.6336, 0.1564, 0.2227]], device='cuda:0')
#
#
#
# D6YQX8MG578K_jpg.rf.29017398e08f76fa48df5664474c635b.jpg
#
# 0 0.36640625 0.509375 0.32421875 0.27265625
#
# tensor([[0.5039, 0.5602, 0.3087, 0.4088],
#         [0.3330, 0.5159, 0.2592, 0.2758]], device='cuda:0')
#
#
#
# db99d5ceca352e32_jpg.rf.b4780c26508b15bf8a41f512aa2bfa66.jpg
#
# 0 0.50703125 0.5546875 0.4875 0.79921875
#
# tensor([[0.5037, 0.5642, 0.4846, 0.7921]], device='cuda:0')
#
#
#
# DD27KVG7DCZ0_jpg.rf.8bd436e461986f379ecca21e6cc420b4.jpg
#
# 1 0.5375 0.6328125 0.52109375 0.57109375
#
# tensor([[0.5454, 0.6434, 0.4936, 0.5524]], device='cuda:0')
#
#
#
# DLKJO4AEO5AF_jpg.rf.d1e29b1d012a477acfd469efae770a68.jpg
#
# 0 0.46484375 0.74375 0.24296875 0.2171875
#
# tensor([[0.7403, 0.2620, 0.4619, 0.4764],
#         [0.4630, 0.7406, 0.2471, 0.2296]], device='cuda:0')
#
#
#
# DMP874XD4TPR_jpg.rf.0870eae8110f35e878072b888ad8669f.jpg
#
# 0 0.4265625 0.56875 0.853125 0.80625
# 1 0.759375 0.3828125 0.48125 0.56875
#
# tensor([[0.4624, 0.5750, 0.9065, 0.8251]], device='cuda:0')
#
#
#
# DO5ZXMLM1VOQ_jpg.rf.39b701763d2b9d42308d21c6f66fb44e.jpg
#
# 1 0.221875 0.53515625 0.17578125 0.30390625
#
# tensor([[0.2250, 0.5369, 0.1762, 0.2938],
#         [0.9219, 0.0486, 0.1563, 0.0972]], device='cuda:0')
#
#
#
# DSBIPBSX15QT_jpg.rf.b72507a1685e89180982c0cace3e9f52.jpg
#
# 1 0.4125 0.7671875 0.57578125 0.46484375
#
# tensor([[0.4081, 0.7601, 0.5591, 0.4798]], device='cuda:0')
#
#
#
# DUS2PHT5PC1Y_jpg.rf.70223b4c30283359ef1a1b6975bee094.jpg
#
# 1 0.2078125 0.8078125 0.153125 0.2234375
# 1 0.38671875 0.8 0.115625 0.18359375
# 1 0.62890625 0.7890625 0.13125 0.19140625
# 1 0.72421875 0.796875 0.09140625 0.18984375
#
# tensor([[0.2067, 0.8178, 0.1555, 0.2403],
#         [0.6271, 0.8018, 0.1325, 0.1990],
#         [0.3798, 0.7914, 0.1119, 0.1713],
#         [0.7248, 0.7970, 0.1018, 0.1904]], device='cuda:0')
#
#
#
# DZMUH4G1AT49_jpg.rf.4cf0dea62951ff7c54bfdba4212fcf41.jpg
#
# 0 0.4734375 0.57578125 0.41484375 0.728125
#
# tensor([[0.4704, 0.5894, 0.4260, 0.6967]], device='cuda:0')
#
#
#
# E5XO6MSFBJ5H_jpg.rf.12a8dc281009702f0505ff62c968e1f7.jpg
#
# 1 0.70390625 0.40234375 0.45234375 0.64140625
#
# tensor([[0.7013, 0.4018, 0.4525, 0.6408]], device='cuda:0')
#
#
#
# EIHD1RDWGKYQ_jpg.rf.28838f27fa07fae56c148186906f8d6f.jpg
#
# 1 0.47734375 0.7734375 0.4296875 0.453125
#
# tensor([[0.4814, 0.7692, 0.4392, 0.4576],
#         [0.9677, 0.7013, 0.0646, 0.2230]], device='cuda:0')
#
#
#
# EMSXXCZ63GJJ_jpg.rf.ac858ddf9daef0e92d117f2280fd3732.jpg
#
# 1 0.6140625 0.74375 0.771875 0.51171875
#
# tensor([[0.6091, 0.7521, 0.7819, 0.4959]], device='cuda:0')
#
#
#
# EN7F716K5A3X_jpg.rf.0ae3f99bd1a40171840274771b625e87.jpg
#
# 1 0.5 0.603125 1.0 0.79375
# 1 0.17265625 0.290625 0.3453125 0.58125
#
# tensor([[0.4971, 0.5003, 0.9929, 0.9994]], device='cuda:0')
#
#
#
# ERVP8P32HNE1_jpg.rf.8c89459b52e8df4f2ddafb7ac0f30afc.jpg
#
# 1 0.44765625 0.390625 0.55703125 0.78046875
#
# tensor([[0.4460, 0.3895, 0.5739, 0.7790]], device='cuda:0')
#
#
#
# EVNKEIDKB002_jpg.rf.984f41eec35ddae765961fec7e0474a4.jpg
#
# 0 0.59140625 0.6578125 0.63671875 0.684375
# 0 0.46953125 0.49453125 0.03125 0.09765625
#
# tensor([], device='cuda:0', size=(0, 4))
#
#
#
# F5YJUBEX1174_jpg.rf.158eabff28a110071e9317f38037c1e1.jpg
#
# 1 0.5140625 0.74921875 0.18203125 0.4203125
#
# tensor([[0.5056, 0.7393, 0.1825, 0.4372],
#         [0.5565, 0.7323, 0.2734, 0.4562],
#         [0.4672, 0.7387, 0.2619, 0.4362]], device='cuda:0')
#
#
#
# F8QB1RGSFA9P_jpg.rf.e215304d1aee73c97e647e08b05ff4a3.jpg
#
# 1 0.140625 0.571875 0.278125 0.85625
# 1 0.75078125 0.51640625 0.4984375 0.9671875
#
# tensor([[0.1561, 0.5700, 0.3122, 0.8599],
#         [0.7306, 0.5077, 0.5381, 0.9538]], device='cuda:0')
#
#
#
# G9B54YXP533D_jpg.rf.a701eb798976c7c54f976d899ccf7c7d.jpg
#
# 1 0.5796875 0.725 0.46953125 0.35859375
#
# tensor([[0.5759, 0.7262, 0.4629, 0.3623]], device='cuda:0')
#
#
#
# G9HY742SZDNS_jpg.rf.2de89b7fe71b2bdf93f39653caa17d46.jpg
#
# 1 0.6015625 0.50546875 0.54375 0.9890625
#
# tensor([[0.6016, 0.4692, 0.5491, 0.9227]], device='cuda:0')
#
#
#
# gettyimages-1171179430-612x612_jpg.rf.7408794870a21b3029dd55c5af06822a.jpg
#
# 0 0.5 0.8515625 1.0 0.296875
# 0 0.22265625 0.59140625 0.29375 0.4625
# 0 0.49765625 0.5359375 0.209375 0.35859375
# 0 0.64765625 0.54140625 0.1359375 0.3703125
# 0 0.7921875 0.5703125 0.1671875 0.37890625
#
# tensor([[0.4967, 0.5458, 0.2071, 0.3459],
#         [0.6474, 0.5483, 0.1457, 0.3495],
#         [0.2111, 0.5870, 0.2735, 0.4502],
#         [0.5000, 0.8401, 0.9971, 0.3197]], device='cuda:0')
#
#
#
# gettyimages-1256441029-612x612_jpg.rf.3a9de3e5c99f308c5bc70e286b5a5b51.jpg
#
# 1 0.22421875 0.73046875 0.2875 0.5390625
# 1 0.796875 0.85859375 0.40625 0.2828125
# 1 0.659375 0.5859375 0.215625 0.43984375
# 1 0.540625 0.49609375 0.0828125 0.35546875
#
# tensor([[0.2265, 0.7385, 0.2885, 0.5230],
#         [0.6614, 0.5841, 0.2224, 0.4047],
#         [0.7908, 0.8609, 0.4179, 0.2781],
#         [0.5443, 0.4992, 0.0675, 0.3239],
#         [0.6516, 0.0378, 0.0841, 0.0756],
#         [0.1625, 0.0372, 0.2177, 0.0740]], device='cuda:0')
#
#
#
# gettyimages-1257380436-612x612_jpg.rf.825bb892c32e6c7d57fb91fe78988e89.jpg
#
# 1 0.46875 0.82734375 0.359375 0.3453125
#
# tensor([[0.4657, 0.8363, 0.3615, 0.3274]], device='cuda:0')
#
#
#
# gettyimages-1310099299-612x612_jpg.rf.d91339e85737c5df5a750877d0fe5ae1.jpg
#
# 1 0.421875 0.78671875 0.4640625 0.4265625
#
# tensor([[0.4245, 0.7961, 0.4488, 0.4076]], device='cuda:0')
#
#
#
# gettyimages-163198630-612x612_jpg.rf.2968ffc7077e2abca461ec9a012fbbd4.jpg
#
# 0 0.11015625 0.63125 0.1734375 0.37109375
# 0 0.36796875 0.703125 0.30546875 0.4625
# 0 0.72578125 0.41953125 0.096875 0.1953125
#
# tensor([[0.3675, 0.7172, 0.3002, 0.4450],
#         [0.1095, 0.6292, 0.1709, 0.3581],
#         [0.6373, 0.4367, 0.0632, 0.1416],
#         [0.7231, 0.4271, 0.1147, 0.1840]], device='cuda:0')
#
#
#
# GO5P6XTESHXQ_jpg.rf.79f642e12017da3a27f9cde5695a6176.jpg
#
# 0 0.75234375 0.63125 0.2109375 0.44140625
#
# tensor([[0.7506, 0.6261, 0.2175, 0.4304]], device='cuda:0')
#
#
#
# GTGUX35309V1_jpg.rf.39ef21880bea130a74eb665ef1638689.jpg
#
# 1 0.47421875 0.734375 0.45703125 0.3125
#
# tensor([[0.4745, 0.7312, 0.4651, 0.3041]], device='cuda:0')
#
#
#
# GUCDIRXNU2IC_jpg.rf.c6ceee4734db1d2b415dd517d4c31f15.jpg
#
# 1 0.47578125 0.46875 0.75546875 0.878125
#
# tensor([[0.4730, 0.4711, 0.7560, 0.8732]], device='cuda:0')
#
#
#
# H45RLHBVZAXW_jpg.rf.851db8d0969b379e1b0ba4ed2e6638d7.jpg
#
# 1 0.6515625 0.68671875 0.65859375 0.55234375
#
# tensor([[0.6579, 0.6984, 0.6655, 0.5355]], device='cuda:0')
#
#
#
# H5FWBZJKY0NR_jpg.rf.39b468384b82e4b28c8f1e0d36e258c5.jpg
#
# 1 0.58828125 0.5546875 0.471875 0.8015625
#
# tensor([[0.5909, 0.4504, 0.4561, 0.5875],
#         [0.5810, 0.5699, 0.4597, 0.7810]], device='cuda:0')
#
#
#
# HAFBHP9LYRGT_jpg.rf.3a535558c79f45e534fc555efa898e74.jpg
#
# 1 0.4828125 0.42421875 0.796875 0.8484375
#
# tensor([[0.5099, 0.4173, 0.8820, 0.8347]], device='cuda:0')
#
#
#
# I0YZLUQG0NPA_jpg.rf.23ad93a8cb7ef904876ea2361b9f6f0e.jpg
#
# 1 0.540625 0.82265625 0.271875 0.35390625
#
# tensor([[0.5688, 0.8076, 0.4710, 0.3840]], device='cuda:0')
#
#
#
# IMG_20230816_122148_jpg.rf.e3668ebefc4cc4c6346aa4450f2b1013.jpg
#
# 0 0.4796875 0.50703125 0.81640625 0.9859375
#
# tensor([[0.4885, 0.5152, 0.8642, 0.9695]], device='cuda:0')
#
#
#
# IMG_20230816_122203_jpg.rf.8dd46742671a3b7411f8be2ec0056ecd.jpg
#
# 0 0.41875 0.4640625 0.8375 0.784375
# 0 0.63359375 0.1484375 0.25859375 0.20859375
# 0 0.34921875 0.12578125 0.30078125 0.18359375
#
# tensor([[0.4300, 0.5066, 0.8574, 0.9505],
#         [0.6665, 0.1767, 0.4628, 0.3520],
#         [0.0610, 0.2746, 0.1220, 0.5250],
#         [0.4285, 0.1081, 0.3021, 0.1998],
#         [0.3092, 0.1008, 0.3222, 0.1950],
#         [0.3934, 0.1121, 0.1860, 0.1812],
#         [0.4245, 0.1048, 0.4526, 0.2083],
#         [0.2762, 0.1035, 0.2460, 0.1719]], device='cuda:0')
#
#
#
# IMG_20230816_122437_1_jpg.rf.0ecb18585d9eacbdc7c7d4b20a0234fd.jpg
#
# 0 0.41328125 0.38984375 0.57109375 0.58671875
# 0 0.56875 0.1203125 0.1375 0.15234375
# 0 0.2640625 0.209375 0.18203125 0.3109375
# 0 0.14375 0.175 0.11953125 0.28671875
#
# tensor([[0.4171, 0.3572, 0.5773, 0.6555]], device='cuda:0')
#
#
#
# IMG_20230816_122525_jpg.rf.db2575b5e1e34cc8812a107431e8936d.jpg
#
# 0 0.4546875 0.446875 0.909375 0.89375
#
# tensor([[0.4511, 0.3982, 0.8985, 0.7786]], device='cuda:0')
#
#
#
# IMG_20230816_122658_1_jpg.rf.043d69622069c410033ed5627c6e2582.jpg
#
# 0 0.40390625 0.5515625 0.73125 0.89609375
#
# tensor([[0.3945, 0.5535, 0.7534, 0.8821]], device='cuda:0')
#
#
#
# IMG_20230816_122737_jpg.rf.a553d64b8bbd6966adb192147d68f248.jpg
#
# 0 0.4359375 0.34765625 0.20703125 0.22265625
#
# tensor([[0.4359, 0.3483, 0.1923, 0.2167],
#         [0.2869, 0.8570, 0.5738, 0.2861]], device='cuda:0')
#
#
#
# IMG_20230816_122848_1_jpg.rf.e280dfa2c643d3fd456fbc10a06d7fad.jpg
#
# 0 0.421875 0.5 0.84375 0.75
#
# tensor([[0.4295, 0.8277, 0.8557, 0.3446],
#         [0.3914, 0.5264, 0.7829, 0.7999]], device='cuda:0')
#
#
#
# IMG_20230816_123019_1_jpg.rf.79473d2d602bf5ea5ebbd4d3f77f0245.jpg
#
# 0 0.43125 0.6859375 0.8625 0.628125
#
# tensor([[0.4344, 0.6798, 0.8684, 0.6373]], device='cuda:0')
#
#
#
# IMG_20230816_123057_jpg.rf.58f82a563b64c9b98fa8ceb378d9429c.jpg
#
# 0 0.53203125 0.59140625 0.9328125 0.8171875
#
# tensor([[0.5150, 0.5913, 0.9308, 0.8173]], device='cuda:0')
#
#
#
# IMG_20230816_161507_1_jpg.rf.25eb0c9caab51e04d363515bb54aec68.jpg
#
# 0 0.38671875 0.5890625 0.7734375 0.821875
#
# tensor([[0.3854, 0.5936, 0.7702, 0.8129]], device='cuda:0')
#
#
#
# IMG_20230816_161522_1_jpg.rf.cb53e7da3e06a51a6ddd769168401b0a.jpg
#
# 0 0.471875 0.56640625 0.65 0.8671875
#
# tensor([[0.4728, 0.5595, 0.6434, 0.8811]], device='cuda:0')
#
#
#
# IRLWJJKFVGKE_jpg.rf.c53f0b0b562e6ac8144d35d64ef26a4c.jpg
#
# 0 0.528125 0.60078125 0.36171875 0.55390625
# 0 0.16015625 0.2234375 0.09375 0.134375
# 0 0.071875 0.22578125 0.09921875 0.15078125
# 1 0.6484375 0.22421875 0.11484375 0.171875
#
# tensor([[0.5244, 0.5994, 0.3750, 0.5583]], device='cuda:0')
#
#
#
# istockphoto-1067203316-612x612_jpg.rf.8b92b892495b168327f19fd58d012d7f.jpg
#
# 1 0.196875 0.7515625 0.384375 0.496875
#
# tensor([[0.1952, 0.7481, 0.3901, 0.5039]], device='cuda:0')
#
#
#
# istockphoto-1217404550-612x612_jpg.rf.935e886743a0837e0961922abd015193.jpg
#
# 0 0.51796875 0.81640625 0.21484375 0.3671875
#
# tensor([[0.5154, 0.8184, 0.2190, 0.3631]], device='cuda:0')
#
#
#
# istockphoto-1297552272-612x612_jpg.rf.1645733da388bbea68f6fcd25192a71c.jpg
#
# 1 0.6234375 0.56484375 0.61171875 0.86953125
#
# tensor([[0.6155, 0.5720, 0.6063, 0.8561]], device='cuda:0')
#
#
#
# istockphoto-1362283281-640x640_jpg.rf.022d30e465245bf38897d27ca56b3c83.jpg
#
# 1 0.57421875 0.884375 0.37734375 0.23125
#
# tensor([[0.5928, 0.8842, 0.4149, 0.2316],
#         [0.1324, 0.3349, 0.2648, 0.2526]], device='cuda:0')
#
#
#
# istockphoto-1414179274-612x612_jpg.rf.869a344631d336658477a7b51e85d20b.jpg
#
# 1 0.60625 0.70078125 0.1546875 0.26015625
#
# tensor([[0.6042, 0.6977, 0.1639, 0.2717]], device='cuda:0')
#
#
#
# istockphoto-1434035471-612x612_jpg.rf.4a05f65abdf6aed7d8763054e53c85ef.jpg
#
# 1 0.48828125 0.5 0.66171875 1.0
#
# tensor([[0.4819, 0.3545, 0.6994, 0.7069]], device='cuda:0')
#
#
#
# istockphoto-1440968793-612x612_jpg.rf.9f39d8163f8240b6294e4c786e128fbe.jpg
#
#
# tensor([[0.5076, 0.5755, 0.4606, 0.6373]], device='cuda:0')
#
#
#
# istockphoto-1452145403-612x612_jpg.rf.765960f3d5ea46f60ffaeb85c7a5929a.jpg
#
#
# tensor([[0.3455, 0.7661, 0.2128, 0.3817]], device='cuda:0')
#
#
#
# istockphoto-1500715792-612x612_jpg.rf.a6ff96f5dcbdecd24df611c8f74b59b4.jpg
#
# 1 0.590625 0.7828125 0.52109375 0.43359375
#
# tensor([[0.5933, 0.7777, 0.5381, 0.4446]], device='cuda:0')
#
#
#
# istockphoto-1585138824-640x640_jpg.rf.ea40c3daa0079ea8c3a9f9b0abd09dd3.jpg
#
# 1 0.240625 0.7875 0.1984375 0.42421875
#
# tensor([[0.4619, 0.9419, 0.1317, 0.1162]], device='cuda:0')
#
#
#
# istockphoto-180729544-2048x2048_jpg.rf.19e7087e5ad0dc1eca4f2a472184cb14.jpg
#
#
# tensor([], device='cuda:0', size=(0, 4))
#
#
#
# istockphoto-578298208-612x612_jpg.rf.0df1955044eaed64f420c032ddc0c21f.jpg
#
# 1 0.565625 0.69453125 0.4671875 0.61015625
#
# tensor([[0.5598, 0.6930, 0.4748, 0.6137]], device='cuda:0')
#
#
#
# IT6SH42UBNPK_jpg.rf.f762a31d068aa652fc17813515db3deb.jpg
#
# 1 0.50859375 0.4875 0.9359375 0.93671875
#
# ...
#
#
#
# sp-5-_jpg.rf.cc2c0b553a99ecb828441e9106dd311f.jpg
#
# 1 0.47109375 0.48671875 0.57265625 0.84765625
#
# tensor([[0.4905, 0.4930, 0.6264, 0.8316]], device='cuda:0')
#
#
#
# sp-59-_jpg.rf.448098142700e6bd883bc67a3ce330a7.jpg
#
# 1 0.41484375 0.5015625 0.78359375 0.7703125
#
# tensor([[0.4105, 0.5008, 0.8060, 0.7486]], device='cuda:0')
#
#
#
# sp-61-_jpg.rf.4f15ba3df995f6bf547004672ab464f2.jpg
#
# 1 0.50234375 0.61796875 0.30390625 0.68515625
#
# tensor([[0.5020, 0.6116, 0.3036, 0.7138]], device='cuda:0')
#
#
#
# sp-62-_jpg.rf.0e94f333628d8a0d0073471df993f01a.jpg
#
# 1 0.45546875 0.73203125 0.32109375 0.30390625
#
# tensor([], device='cuda:0', size=(0, 4))
#
#
#
# sp-66-_jpg.rf.aed03a93040d31558667f289cf45a3ff.jpg
#
# 1 0.5796875 0.5578125 0.834375 0.884375
#
# tensor([[0.6008, 0.5580, 0.7983, 0.8840]], device='cuda:0')
#
#
#
# sp-69-_jpg.rf.9a60b77b5059c6ef6c2375febbfe834a.jpg
#
# 1 0.55 0.64375 0.53203125 0.64140625
#
# tensor([[0.5589, 0.6500, 0.5430, 0.6616]], device='cuda:0')
#
#
#
# sp-72-_jpg.rf.b4fa7ee5042e3f16815d8d0d3e3f8013.jpg
#
# 1 0.49140625 0.50390625 0.9828125 0.7109375
#
# tensor([[0.4989, 0.5536, 0.9904, 0.7004]], device='cuda:0')
#
#
#
# sp-85-_jpg.rf.7fe5b89a790063185f19a5a7d699a780.jpg
#
# 1 0.9015625 0.51015625 0.196875 0.3453125
#
# tensor([[0.9009, 0.5174, 0.1945, 0.3255]], device='cuda:0')
#
#
#
# sp-87-_jpg.rf.eebb0b5c4b6cd77cdb5169a3b3b697ed.jpg
#
# 1 0.5078125 0.60390625 0.696875 0.76953125
#
# tensor([[0.5293, 0.5917, 0.7263, 0.8166]], device='cuda:0')
#
#
#
# sp-88-_jpg.rf.1d9d06e7376e17636e82b1ba62927f46.jpg
#
# 1 0.73671875 0.675 0.3921875 0.4671875
#
# tensor([[0.7353, 0.6775, 0.3951, 0.4624],
#         [0.9627, 0.3996, 0.0747, 0.3974]], device='cuda:0')
#
#
#
# sp-93-_jpg.rf.f6da0524a509e1b95e0caf9e6facae83.jpg
#
# 1 0.546875 0.715625 0.85390625 0.56875
#
# tensor([[0.5610, 0.8234, 0.7988, 0.3529]], device='cuda:0')
#
#
#
# sp-96-_jpg.rf.897f37fc6e8d1040996597ae5f30b68b.jpg
#
# 1 0.5 0.48046875 0.8 0.88046875
#
# tensor([[0.5100, 0.4894, 0.7938, 0.9077]], device='cuda:0')
#
#
#
# sp-98-_jpg.rf.7284ebe254c044f5f91f1aa262cbd8be.jpg
#
# 1 0.434375 0.60625 0.165625 0.36796875
#
# tensor([[0.4363, 0.6033, 0.1537, 0.3666]], device='cuda:0')
#
#
#
# SRD75VB1C2PI_jpg.rf.b1fdbf67b899e23c80c8357ce67a6182.jpg
#
# 0 0.7671875 0.5890625 0.325 0.48203125
# 1 0.184375 0.4078125 0.15703125 0.24453125
#
# tensor([[0.7647, 0.5955, 0.3190, 0.4781]], device='cuda:0')
#
#
#
# TBJGC1KIMA6L_jpg.rf.e15e5d1397d8846920f36c59b33f65fa.jpg
#
# 1 0.33984375 0.5640625 0.6796875 0.871875
#
# tensor([[0.3434, 0.5669, 0.6805, 0.8662],
#         [0.7320, 0.6294, 0.5359, 0.7360],
#         [0.1489, 0.5437, 0.2978, 0.8093]], device='cuda:0')
#
#
#
# TCFV3KADD48S_jpg.rf.f0cf253a3246dfb7956e36c2b02552b0.jpg
#
# 1 0.5 0.73828125 1.0 0.5234375
#
# tensor([[0.5000, 0.7296, 0.9999, 0.5381],
#         [0.5007, 0.4935, 0.9984, 0.9870]], device='cuda:0')
#
#
#
# TESSG3VRY0ZG_jpg.rf.a98c4b8037f7ccfd294adf7eacb35640.jpg
#
# 1 0.49609375 0.71640625 0.8984375 0.51484375
#
# tensor([[0.5059, 0.7310, 0.9118, 0.5288],
#         [0.4600, 0.2629, 0.2673, 0.2187]], device='cuda:0')
#
#
#
# THKPYQOHFVCH_jpg.rf.c44bdf6588bd84d64a3beaee850e5767.jpg
#
# 0 0.47578125 0.50078125 0.83515625 0.915625
#
# tensor([[0.4403, 0.4867, 0.8806, 0.9346],
#         [0.0672, 0.1098, 0.1344, 0.2194],
#         [0.1794, 0.1005, 0.3547, 0.2011]], device='cuda:0')
#
#
#
# TIDUSXSOGO8E_jpg.rf.8f0af4d39d9cffa94a468b9056e8948d.jpg
#
# 1 0.559375 0.4859375 0.49921875 0.92734375
#
# tensor([[0.5543, 0.4974, 0.5204, 0.9295]], device='cuda:0')
#
#
#
# TQHLDP8RAUY5_jpg.rf.10870a9ea06e83a14b90f02d04c18d4e.jpg
#
# 1 0.2921875 0.3421875 0.578125 0.58671875
#
# tensor([[0.2975, 0.5056, 0.5927, 0.9690]], device='cuda:0')
#
#
#
# TUEIUSUAWK1B_jpg.rf.66192f451536fb49a8b68076a7dda4d8.jpg
#
# 1 0.3421875 0.1953125 0.13671875 0.26484375
# 1 0.15859375 0.41484375 0.1375 0.2703125
# 1 0.28046875 0.41953125 0.13046875 0.26640625
# 1 0.4078125 0.41796875 0.14453125 0.28515625
# 1 0.8015625 0.18671875 0.1421875 0.25
# 1 0.73984375 0.4234375 0.13203125 0.26796875
# 1 0.86953125 0.43125 0.1203125 0.26796875
# 1 0.0984375 0.6375 0.11640625 0.28359375
# 1 0.2203125 0.653125 0.1203125 0.26484375
# 1 0.3390625 0.65546875 0.11171875 0.26640625
# 1 0.45 0.653125 0.1234375 0.28828125
# 1 0.56796875 0.6546875 0.125 0.29140625
# 1 0.6859375 0.65625 0.125 0.28125
# 1 0.92265625 0.659375 0.12265625 0.278125
# 1 0.8015625 0.659375 0.12109375 0.275
# 1 0.04921875 0.86484375 0.09765625 0.2703125
# 1 0.1546875 0.88203125 0.10625 0.2359375
# 1 0.2640625 0.878125 0.11875 0.24375
# 1 0.38125 0.87890625 0.128125 0.2421875
# 1 0.50078125 0.875 0.11875 0.25
# 1 0.621875 0.87734375 0.11875 0.2453125
# 1 0.74375 0.87734375 0.125 0.2453125
# 1 0.8484375 0.87734375 0.12109375 0.2453125
# 1 0.94765625 0.8765625 0.1046875 0.246875
#
# tensor([[0.5663, 0.5767, 0.1131, 0.1361],
#         [0.3366, 0.1789, 0.1305, 0.2518],
#         [0.8020, 0.1868, 0.1370, 0.2555],
#         [0.1608, 0.3946, 0.1305, 0.2432],
#         [0.4013, 0.4068, 0.1223, 0.2403],
#         [0.2690, 0.8903, 0.1278, 0.2185],
#         [0.1170, 0.6204, 0.1618, 0.2334],
#         [0.7377, 0.4042, 0.1184, 0.2467],
#         [0.5007, 0.8900, 0.1258, 0.2200],
#         [0.6153, 0.8926, 0.1189, 0.2147],
#         [0.3885, 0.8905, 0.1214, 0.2176],
#         [0.1616, 0.8939, 0.1155, 0.2118],
#         [0.2818, 0.4005, 0.1198, 0.2429],
#         [0.3357, 0.6588, 0.1184, 0.2152],
#         [0.0467, 0.9229, 0.0934, 0.1530],
#         [0.7339, 0.8891, 0.1241, 0.2217],
#         [0.9245, 0.8658, 0.1508, 0.2674]], device='cuda:0')
#
#
#
# tuscany-italy-closeup-three-italian-people-coronavirus-protective-masks-line-shopping-carts-waiting-to-buy-food-179562854_jpg.rf.c6426973ce146dbc66f0bb637e41e4a0.jpg
#
# 1 0.4359375 0.759375 0.253125 0.42890625
# 1 0.55078125 0.8765625 0.26171875 0.24609375
#
# tensor([[0.5966, 0.8742, 0.2848, 0.2516],
#         [0.4438, 0.7737, 0.2182, 0.4526],
#         [0.1872, 0.5910, 0.1333, 0.3604]], device='cuda:0')
#
#
#
# TWJ6TLM2YHHL_jpg.rf.8cc54c092cd1dfcd07aae0ab6eede0af.jpg
#
# 1 0.39296875 0.67109375 0.2453125 0.46484375
#
# tensor([[0.3922, 0.6659, 0.2542, 0.4595],
#         [0.2348, 0.6099, 0.2579, 0.4472]], device='cuda:0')
#
#
#
# TX0KMS2JGT4M_jpg.rf.84f9e1dbb4d449dca6b360ae49b31b91.jpg
#
# 0 0.56875 0.56015625 0.4890625 0.75390625
#
# tensor([[0.5554, 0.5882, 0.5260, 0.7912]], device='cuda:0')
#
#
#
# TXSSP2K7QZIM_jpg.rf.32ce0c53aa261671642743eb01a04acc.jpg
#
# 1 0.6234375 0.5921875 0.6359375 0.6921875
#
# tensor([[0.6213, 0.5532, 0.6521, 0.8044],
#         [0.8460, 0.0198, 0.2142, 0.0381]], device='cuda:0')
#
#
#
# TZESLCMWHUM1_jpg.rf.49277bc98323e777f63195e4b328ee91.jpg
#
# 1 0.48203125 0.50078125 0.6796875 0.9984375
#
# tensor([[0.4779, 0.5002, 0.6921, 0.9997]], device='cuda:0')
#
#
#
# U5F1MUKBNRLX_jpg.rf.2d2d7f29a71e380b0ae26e9ca1278ee4.jpg
#
# 0 0.315625 0.4703125 0.5640625 0.934375
# 1 0.7671875 0.41640625 0.17734375 0.26015625
#
# tensor([[0.7708, 0.4051, 0.1699, 0.2408],
#         [0.3645, 0.4796, 0.4580, 0.9369]], device='cuda:0')
#
#
#
# U5TAF5YFHZ81_jpg.rf.6d6c18b612912fd2ad3c84b61841d6a2.jpg
#
# 1 0.365625 0.70625 0.17890625 0.41171875
# 1 0.55078125 0.709375 0.190625 0.40625
# 1 0.740625 0.70625 0.23203125 0.41171875
#
# tensor([[0.3654, 0.7165, 0.2216, 0.4061],
#         [0.5421, 0.7105, 0.1971, 0.4063],
#         [0.7372, 0.7085, 0.2505, 0.4206]], device='cuda:0')
#
#
#
# U90TTGNZM8HS_jpg.rf.35f408bbf7f9cc3ad382ab95d86a0892.jpg
#
# 0 0.50390625 0.5296875 0.99140625 0.93984375
#
# tensor([[0.5000, 0.5083, 1.0000, 0.9493]], device='cuda:0')
#
#
#
# U91KGF91TF0N_jpg.rf.06240d376424e198c453225aad7eefbf.jpg
#
# 1 0.51875 0.625 0.80390625 0.64609375
#
# tensor([[0.5084, 0.6263, 0.8021, 0.6458]], device='cuda:0')
#
#
#
# UED5G2MC6O3W_jpg.rf.2bb1ae4d95f7208c1178d1684b93980b.jpg
#
# 1 0.31015625 0.51484375 0.60859375 0.89609375
#
# tensor([[0.3073, 0.5117, 0.6146, 0.8990]], device='cuda:0')
#
#
#
# UJMSYH1XADCI_jpg.rf.6a2061202db7147edf0bd2189724357f.jpg
#
# 0 0.28359375 0.61171875 0.1375 0.1984375
#
# tensor([[0.2878, 0.6109, 0.1447, 0.1934]], device='cuda:0')
#
#
#
# UP3ZAVSJOCNU_jpg.rf.464e261420da2157b5066e36cb116d97.jpg
#
# 1 0.31015625 0.7203125 0.3359375 0.44765625
#
# tensor([[0.3070, 0.7249, 0.3313, 0.4388]], device='cuda:0')
#
#
#
# UU86UD90QLST_jpg.rf.29a735b56fd9a6d5ec0014dfe79b823b.jpg
#
# 1 0.5 0.5875 1.0 0.825
#
# tensor([[0.4999, 0.5811, 0.9998, 0.8377]], device='cuda:0')
#
#
#
# V3PTZ5Z90SNU_jpg.rf.8e1f53f8021e0a71e920036386bdba13.jpg
#
# 1 0.36015625 0.57421875 0.7203125 0.81015625
# 1 0.61640625 0.33984375 0.56640625 0.6796875
#
# tensor([[0.3917, 0.5643, 0.7823, 0.8687],
#         [0.4929, 0.4780, 0.7697, 0.9435]], device='cuda:0')
#
#
#
# V5CWA3599S13_jpg.rf.f1fffb77629e2f89e41864d66c71c2df.jpg
#
# 1 0.50234375 0.66015625 0.6109375 0.6796875
# 1 0.390625 0.3703125 0.4203125 0.29375
# 1 0.4921875 0.20625 0.29921875 0.05234375
#
# tensor([[0.5007, 0.6699, 0.6151, 0.6400],
#         [0.4850, 0.6132, 0.6444, 0.7620]], device='cuda:0')
#
#
#
# VBGM4U8M9F9Q_jpg.rf.648b7b56896ad352a720c0a36b29770d.jpg
#
# 1 0.75234375 0.69765625 0.240625 0.4015625
#
# tensor([[0.7519, 0.7027, 0.2539, 0.3962]], device='cuda:0')
#
#
#
# VBZ85AWY8UX8_jpg.rf.149586e090e269592d4407c3918319a3.jpg
#
# 1 0.45859375 0.70859375 0.22734375 0.2046875
#
# tensor([[0.4538, 0.7063, 0.2091, 0.2049]], device='cuda:0')
#
#
#
# VHOFC9A6QTXQ_jpg.rf.4243b5dc3027bd3083ff624c408c4304.jpg
#
# 1 0.4625 0.53515625 0.759375 0.6984375
#
# tensor([[0.4673, 0.5301, 0.7904, 0.6874]], device='cuda:0')
#
#
#
# VLNGZSXXFEUT_jpg.rf.5acf02f3fae964939597fffef7102a79.jpg
#
# 1 0.5078125 0.8015625 0.36484375 0.3046875
#
# tensor([[0.5076, 0.8350, 0.3730, 0.3237]], device='cuda:0')
#
#
#
# VMGU684XFNJP_jpg.rf.55b09719e7ce27711c05e9b5bd6e3a96.jpg
#
# 0 0.509375 0.54296875 0.58515625 0.3859375
#
# tensor([[0.5491, 0.6736, 0.6403, 0.6520]], device='cuda:0')
#
#
#
# VO85848545L0_jpg.rf.c35214a8bf3ca308736a14ba26fcb07f.jpg
#
# 1 0.603125 0.634375 0.4234375 0.56015625
#
# tensor([[0.6103, 0.6469, 0.4065, 0.5324],
#         [0.6741, 0.6472, 0.2774, 0.5320]], device='cuda:0')
#
#
#
# VTX24YN23CZ0_jpg.rf.b6d4f6571690ad323108eaa99309a8fc.jpg
#
# 1 0.375 0.540625 0.45859375 0.26953125
#
# tensor([[0.3466, 0.6537, 0.5364, 0.5869]], device='cuda:0')
#
#
#
# VYTQM924C85T_jpg.rf.be0c9842c83d9744dd991a9e2bd0b68b.jpg
#
# 0 0.5671875 0.57734375 0.7140625 0.8015625
#
# tensor([[0.4575, 0.4395, 0.5489, 0.4577]], device='cuda:0')
#
#
#
# W0LL89I06DB6_jpg.rf.0968003585ef83f6d7817474e8f814a5.jpg
#
# 1 0.50234375 0.78984375 0.1578125 0.28125
#
# tensor([[0.5019, 0.7881, 0.1580, 0.2745]], device='cuda:0')
#
#
#
# W1ZHG6RQQHVF_jpg.rf.44f605efdffb86d3b259f6c1ff9f4523.jpg
#
# 1 0.68203125 0.7046875 0.2453125 0.4828125
#
# tensor([[0.6743, 0.7101, 0.2350, 0.3410]], device='cuda:0')
#
#
#
# W981QC0623FY_jpg.rf.21237b1db8edcc9407841dd4ec5914e3.jpg
#
# 1 0.6875 0.784375 0.56328125 0.43046875
#
# tensor([[0.6254, 0.7747, 0.4406, 0.4506],
#         [0.7663, 0.7806, 0.4073, 0.4380],
#         [0.5021, 0.1085, 0.9957, 0.2170]], device='cuda:0')
#
#
#
# W9PSIT5TV8DB_jpg.rf.f03e6daf2c9eedd06450f322c230cbd9.jpg
#
# 1 0.5 0.621875 1.0 0.75546875
#
# tensor([[0.5019, 0.6277, 0.9954, 0.7447]], device='cuda:0')
#
#
#
# WDHKKT3FCM27_jpg.rf.71e97bdbd95dacfc283813425c0345e4.jpg
#
# 1 0.27421875 0.51640625 0.12734375 0.17109375
#
# tensor([[0.2586, 0.5348, 0.1619, 0.2101]], device='cuda:0')
#
#
#
# WPM4HQS741GJ_jpg.rf.631ce118590ba191347487a061c8ec6b.jpg
#
# 1 0.69296875 0.53125 0.478125 0.64765625
#
# tensor([[0.6937, 0.5375, 0.4656, 0.6280],
#         [0.2121, 0.0767, 0.1208, 0.1535],
#         [0.0689, 0.0356, 0.1334, 0.0712]], device='cuda:0')
#
#
#
# WQ8SBUPJD42V_jpg.rf.0dd25cf2673e18ac6534f27304d8506e.jpg
#
# 1 0.6953125 0.6328125 0.296875 0.509375
#
# tensor([[0.6878, 0.6247, 0.2933, 0.5127]], device='cuda:0')
#
#
#
# WQLUNF1S0ILP_jpg.rf.812cbb9dc628caf6c3894ba522feddc0.jpg
#
# 1 0.50859375 0.71796875 0.6390625 0.5640625
# 1 0.11796875 0.7203125 0.2359375 0.54140625
# 1 0.85859375 0.72578125 0.2765625 0.54765625
#
# tensor([[0.8750, 0.7166, 0.2499, 0.5177],
#         [0.1147, 0.7142, 0.2295, 0.5687],
#         [0.5063, 0.7147, 0.6221, 0.5697]], device='cuda:0')
#
#
#
# WV82Y7434SBJ_jpg.rf.27114662253ae35809b1e71019631446.jpg
#
# 0 0.4875 0.51953125 0.6 0.9609375
#
# tensor([[0.4754, 0.5353, 0.6376, 0.9284]], device='cuda:0')
#
#
#
# WYVS71124V2Z_jpg.rf.09a7fee4ff327401fd09544b59416913.jpg
#
# 1 0.51015625 0.50234375 0.9796875 0.9953125
#
# tensor([[0.5023, 0.4729, 0.9930, 0.9458]], device='cuda:0')
#
#
#
# X7Y98N2W1ZSB_jpg.rf.fd9ea6f0d2b45e974439872d0eb2f69a.jpg
#
# 1 0.22578125 0.721875 0.165625 0.35
# 1 0.70546875 0.796875 0.21796875 0.40625
# 1 0.91796875 0.771875 0.11796875 0.4296875
# 1 0.46796875 0.6125 0.09921875 0.2
# 1 0.5296875 0.6296875 0.10546875 0.23125
# 1 0.29765625 0.578125 0.0796875 0.16328125
# 1 0.19921875 0.584375 0.1 0.16484375
# 1 0.68125 0.56171875 0.13984375 0.07734375
#
# tensor([[0.2268, 0.6995, 0.1616, 0.3914],
#         [0.7003, 0.7811, 0.2343, 0.4235],
#         [0.5280, 0.6199, 0.0990, 0.2457],
#         [0.9233, 0.7543, 0.1497, 0.3800],
#         [0.4537, 0.5984, 0.0855, 0.2120],
#         [0.2976, 0.5777, 0.0773, 0.1604]], device='cuda:0')
#
#
#
# XC5ZX62LK3R9_jpg.rf.7cc755c7840969b74328e88dc01d8f13.jpg
#
# 1 0.48046875 0.43203125 0.5421875 0.63671875
# 1 0.62890625 0.6203125 0.50234375 0.70625
#
# tensor([[0.6451, 0.5908, 0.4885, 0.7671],
#         [0.4726, 0.4608, 0.5162, 0.6801]], device='cuda:0')
#
#
#
# XD207IYI12I6_jpg.rf.b712cfe57fdd81444f5ccb92a12673ff.jpg
#
# 0 0.28828125 0.79609375 0.4734375 0.3921875
#
# tensor([], device='cuda:0', size=(0, 4))
#
#
#
# XYMVP4QKMEJ0_jpg.rf.47966620a544e2f9a22a48a5b55a8e3f.jpg
#
# 1 0.496875 0.45078125 0.578125 0.83125
#
# tensor([[0.4942, 0.4484, 0.5927, 0.8046]], device='cuda:0')
#
#
#
# Y13OS18ZKBEB_jpg.rf.279cfebd790931a14f0e6f99a5d8393d.jpg
#
# 1 0.7265625 0.7859375 0.43046875 0.36015625
#
# tensor([[0.7213, 0.7937, 0.4217, 0.3537]], device='cuda:0')
#
#
#
# Y96JKJZTAOPT_jpg.rf.d8a54f72846d9d0886e2673fbb912560.jpg
#
# 1 0.65625 0.5234375 0.62578125 0.953125
#
# tensor([[0.6356, 0.5031, 0.6102, 0.9928]], device='cuda:0')
#
#
#
# YFE63AK1IAG3_jpg.rf.a2f27f74ba149b69eba6350a71aecf6b.jpg
#
# 0 0.3125 0.52890625 0.4421875 0.9421875
# 0 0.771875 0.37578125 0.35546875 0.72265625
#
# tensor([[0.3124, 0.5315, 0.4599, 0.9296],
#         [0.7714, 0.3724, 0.3643, 0.7137]], device='cuda:0')
#
#
#
# YM6ZDDQ41CAR_jpg.rf.26ce5d68c3af3e2bc0d72ba2adf444fc.jpg
#
# 1 0.48125 0.3859375 0.2046875 0.1765625
#
# tensor([[0.4394, 0.5391, 0.3602, 0.4835]], device='cuda:0')
#
#
#
# YO54O8X1OLHA_jpg.rf.5cecbaffcb5dc0993dff82f9ecde1835.jpg
#
# 1 0.64921875 0.58125 0.50703125 0.765625
#
# tensor([[0.6536, 0.5888, 0.5038, 0.7668]], device='cuda:0')
#
#
#
# youtube-858_jpg.rf.b924ab878564dd1ca166e43fcc09d8e7.jpg
#
# 1 0.54375 0.78125 0.084375 0.36875
#
# tensor([[0.5471, 0.7517, 0.0925, 0.3170],
#         [0.5510, 0.7947, 0.0841, 0.2447],
#         [0.4574, 0.9716, 0.1244, 0.0569]], device='cuda:0')
#
#
#
# YTG8LBJ1ZBKR_jpg.rf.80e6e402c82a0b326715a7f54c2d7a34.jpg
#
# 1 0.30625 0.559375 0.38671875 0.66953125
#
# tensor([[0.3051, 0.5731, 0.3975, 0.6990]], device='cuda:0')
#
#
#
# YZ5JCHPXPVB9_jpg.rf.65eb0353d7f35107b4252ca528a54cff.jpg
#
# 1 0.50859375 0.521875 0.95234375 0.90546875
#
# tensor([[0.5096, 0.5034, 0.9515, 0.8824]], device='cuda:0')
#
#
#
# Z5394TTN4Y14_jpg.rf.f149e77e8cebd90d7c5580fc49b6d881.jpg
#
# 0 0.3046875 0.83359375 0.609375 0.3296875
#
# tensor([[0.3119, 0.8248, 0.6234, 0.3503]], device='cuda:0')
#
#
#
# ZEGQR7SOM04C_jpg.rf.1fc67e0f944a7cde07f7b34979d427e5.jpg
#
# 1 0.4953125 0.70625 0.65859375 0.56640625
#
# tensor([[0.4811, 0.7203, 0.6186, 0.5485],
#         [0.5611, 0.6642, 0.7754, 0.6698]], device='cuda:0')
#
#
#
# ZETUN7L9BGE0_jpg.rf.a848218b2eb3613bd12974b5c14acefc.jpg
#
# 1 0.284375 0.63125 0.3640625 0.66640625
#
# tensor([[0.2957, 0.5925, 0.3802, 0.6605]], device='cuda:0')
#
#
#
# ZI8H88PCJNNL_jpg.rf.4d9dbf70d23d8e4c82725c7df4c254bb.jpg
#
# 0 0.5328125 0.72734375 0.7453125 0.5453125
#
# tensor([[0.5294, 0.7313, 0.7738, 0.5370]], device='cuda:0')
#
#
#
# ZKEODO4F3VJ7_jpg.rf.554550ce9766616ded21e4712d4bc4f1.jpg
#
# 1 0.53203125 0.59296875 0.73671875 0.5859375
# 1 0.33828125 0.44921875 0.5265625 0.43359375
# 1 0.528125 0.390625 0.40546875 0.33828125
#
# tensor([[0.5286, 0.5559, 0.7516, 0.6240],
#         [0.4049, 0.5500, 0.6509, 0.6442]], device='cuda:0')
#
#
#
# ZPWM2HQ9CGLS_jpg.rf.4176bf6dac8e7eb1970d55d91a31e6c1.jpg
#
# 1 0.3671875 0.47734375 0.43828125 0.83515625
#
# tensor([[0.3706, 0.4780, 0.4283, 0.8246]], device='cuda:0')
#
#
#
# ZQWK8E3E6NN4_jpg.rf.0dada0703b525f497b21b1f9fa5e6618.jpg
#
# 1 0.47265625 0.259375 0.9125 0.321875
#
# tensor([[0.4629, 0.3952, 0.9080, 0.6123]], device='cuda:0')
#
#
#
# ZSKH66VAPQ0B_jpg.rf.5727df8a44a9fb843325c2b1deea52ec.jpg
#
# 1 0.34140625 0.7359375 0.628125 0.52734375
#
# tensor([[0.3419, 0.7388, 0.6526, 0.5224]], device='cuda:0')
